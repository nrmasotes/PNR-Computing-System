# %%
#Author: Nathaniel Hope Masotes & Jonathan Joseph Archog
#Description: An app that seek to help queueing line of the daily passengers in 5 different stations 
#of PNR with the use of data structure: array list and queue.
#Date: 6/22/22

# %%
passenger_queue_tutuban = [] #declare an array list for the queueing of tutuban station to run
passenger_queue_blumentritt = [] #declare an array list for the queueing of blumentritt station to run
passenger_queue_laonlaan = [] #declare an array list for the queueing of laon-laan station to run
passenger_queue_espana = [] #declare an array list for the queueing of espana station to run
passenger_queue_stamesa = [] #declare an array list for the queueing of sta.mesa station to run

# %% [markdown]
# # USER 1

# %%
#importing all the necessary module in building this app 
import tkinter
from tkinter.ttk import Button
import time
import tkinter as tk
from tkinter import *
import datetime as dt
import time as tm
from tkinter import ttk
from PIL import Image, ImageTk


#root window
root = Tk()
root.geometry('900x500+300+200')  
root.title("PNR - Computing Application")
root.resizable(width=False, height=False)

#main picture of PNR Computing System
image1 = Image.open("C:\\Users\\Nath\\Downloads\\PNR (2).png")
test = ImageTk.PhotoImage(image1)
imageLabel = tkinter.Label(image=test)
imageLabel.image = test
imageLabel.place(x=2, y=90)

#UI Design
mainLabel = Label(root, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
mainLabel.pack()
botLabel = Label(root, fg = "white", bg = "#FF8552", width = 150, height = 1)
botLabel.place(y=480)

#Welcome label, email label, and password label
welcomeLabel = Label(root, text = "\nHi! Welcome to PNR Computing System!", font=("Microsoft YaHei UI Bold", 11))
welcomeLabel.place(x = 480, y = 150)
inputLabel=Label(root, text="Please sign in using your email account.", font=("Microsoft YaHei UI Light", 9))
inputLabel.place(x = 500, y = 200)
emailLabel = Label(root, text = "Email:", font = ("Microsoft YaHei UI Light", 9))
emailLabel.place(x = 440, y = 228)
passLabel = Label(root, text = "Password:", font = ("Microsoft YaHei UI Light", 9))
passLabel.place(x = 430, y = 260)

#Email Input 
inputEmail= Entry(root, width= 30)
inputEmail.focus_set()
inputEmail.place(x = 500, y = 230) 
inputEmail.configure(bg = "white")

#Password Input
pass_value = StringVar
inputPass= Entry(root, width= 30, textvariable = pass_value, show = "\u2022")
inputPass.focus_set()
inputPass.place(x = 500, y = 260)
inputPass.configure(bg = "white")

#character limit for password
def character_limit(pass_value):
    if len(pass_value.get()) > 0:
        pass_value.set(pass_value.get()[-1])



#define a message after clicking an account 
def crtaccmessage():
    msg = Label(root, text = "Sorry! creating an account is not yet available.")
    msg.place(x = 490, y = 380)
    
    msg2 = Label(root, text = "Please press Next to proceed.")
    msg2.place(x = 490, y = 395)
    
#create account button    
crtaccbtn = Button (root, text = "Create an Account", command = crtaccmessage, width = 18, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
crtaccbtn.place(x = 490, y = 330)

#Date & Time
date = dt.datetime.now()

dateLabel = Label(root, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
dateLabel.place(x = 720, y = 50)

pstLabel = Label(root, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
pstLabel.place(x = 700, y = 30)


timeLabel = Label(root, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

def clock():
    text_input = time.strftime("%I:%M:%S %p")
    timeLabel.config(text=text_input)
    timeLabel.after(200, clock)
    timeLabel.place(x = 750, y = 70)
    
clock()

#define departure window
def DepartureWindow():
    root.destroy()
    newWindow2 = Tk()
    newWindow2.title("PNR Computing System - Departure List")
    newWindow2.geometry("900x500+300+200")
    newWindow2.resizable(width=False, height=False)
    

    #picture of Departure Point List
    image3 = Image.open("C:\\Users\\Nath\\Downloads\\pnr (8).png")
    test = ImageTk.PhotoImage(image3)
    imageLabel = tkinter.Label(image=test)
    imageLabel.image = test
    imageLabel.place(x=-160, y=-100)
    
    #UI design and departure label
    depFrame = Frame(newWindow2, bg = "white", width = 380, height = 430)
    depFrame.place(x = 500, y = 50)
    depLabel = Label(newWindow2, bg= "white", text = "Which station are you in?", font=("Microsoft YaHei UI Bold", 11))
    depLabel.place(x = 520, y = 150)
    depLabel2 = Label(newWindow2, bg= "white", text = "Choose your station by clicking the button below.", font=("Microsoft YaHei UI Light", 9))
    depLabel2.place(x = 520, y = 180)
    
    #tutuban button
    tutubanbtn = Button (newWindow2, text = "Tutuban", command = tutuban_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutubanbtn.place(x = 530, y = 220)
    blumentrittbtn = Button (newWindow2, text = "Blumentritt", command = blumentritt_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentrittbtn.place(x = 530, y = 270)
    
    #laon-laan button
    laon_laanbtn = Button (newWindow2, text = "Laon-Laan", command = laonlaan_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laon_laanbtn.place(x = 530, y = 320)
    
    #espana button
    espanabtn = Button (newWindow2, text = "España", command = espana_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espanabtn.place(x = 530, y = 370)
    
    #sta.mesa button
    sta_mesabtn = Button (newWindow2, text = "Sta. Mesa", command = stamesa_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    sta_mesabtn.place(x = 530, y = 420)
    
    #current date and time
    date = dt.datetime.now()
    dateLabel = Label(newWindow2, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 9), bg = "white")
    dateLabel.place(x = 720, y = 90)
    pstLabel = Label(newWindow2, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 9, 'bold'), bg = "white")
    pstLabel.place(x = 700, y = 70)
    timeLabel = Label(newWindow2, font=("Microsoft YaHei UI Light", 12, 'bold'), bg="white")
    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 110)
    clock()

    
#next button
nxtbtn = Button (root, text = "Next", command = DepartureWindow, width = 10, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
nxtbtn.place(x = 670, y = 330)


#defines tutuban destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def tutuban_destination():
    newWindow3 = Toplevel()
    newWindow3.title("PNR Computing System - Tutuban Station")
    newWindow3.geometry("900x500+300+200")
    newWindow3.resizable(width=False, height=False)
    
    mainLabel = Label(newWindow3, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow3, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    tutuban_label = Label(newWindow3, text = "Tutuban Southbound Destination List", width = 45, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 15))
    tutuban_label.place(x = 195, y = 110)
    
    tutuban_blumentrittbtn = Button(newWindow3, text = "Blumentritt", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_blumentrittbtn.place(x = 150, y = 180)
    
    tutuban_laonlaanbtn = Button(newWindow3, text = "Laon-Laan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_laonlaanbtn.place(x = 150, y = 215)
    
    tutuban_espanabtn = Button(newWindow3, text = "Espana", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_espanabtn.place(x = 150, y = 250)
    
    tutuban_stamesabtn = Button(newWindow3, text = "Sta. Mesa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_stamesabtn.place(x = 150, y = 285)
    
    tutuban_pandacanbtn = Button(newWindow3, text = "Pandacan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pandacanbtn.place(x = 300, y = 180)
    
    tutuban_pacobtn = Button(newWindow3, text = "Paco", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pacobtn.place(x = 300, y = 215)
    
    tutuban_sanandresbtn = Button(newWindow3, text = "San Andres", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sanandresbtn.place(x = 300, y = 250)
    
    tutuban_vitocruzbtn = Button(newWindow3, text = "Vito Cruz", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_vitocruzbtn.place(x = 300, y = 285)
    
    tutuban_delarosabtn = Button(newWindow3, text = "Dela Rosa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_delarosabtn.place(x = 450, y = 180)
    
    tutuban_pasayrdbtn = Button(newWindow3, text = "Pasay Rd.", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pasayrdbtn.place(x = 450, y = 215)
    
    tutuban_edsabtn = Button(newWindow3, text = "EDSA", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_edsabtn.place(x = 450, y = 250)
    
    tutuban_nicholsbtn = Button(newWindow3, text = "Nichols", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_nicholsbtn.place(x = 450, y = 285)
    
    tutuban_ftibtn = Button(newWindow3, text = "FTI", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_ftibtn.place(x = 600, y = 180)
    
    tutuban_bicutanbtn = Button(newWindow3, text = "Bicutan", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_bicutanbtn.place(x = 600, y = 215)
    
    tutuban_sucatbtn = Button(newWindow3, text = "Sucat", command = lambda:[tutuban_to_sucatinput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sucatbtn.place(x = 600, y = 250)
    
    tutuban_alabangbtn = Button(newWindow3, text = "Alabang", command = lambda:[tutuban_to_alabanginput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_alabangbtn.place(x = 600, y = 285)
    
    
    
    dateLabel = Label(newWindow3, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow3, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow3, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines tutuban to edsa as destination window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsainput():
    ttbnedsaWindow = Toplevel()
    ttbnedsaWindow.title("PNR Computing System")
    ttbnedsaWindow.geometry("900x500+300+200")
    ttbnedsaWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnedsa_label = Label(ttbnedsaWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnedsa_label.place(x = 220, y = 110)
    
    ttbnedsa_aircon = Button(ttbnedsaWindow, text = "Aircon = ₱15.00", command = lambda:[tutuban_to_edsaaircon(), ttbnedsaWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_aircon.place(x = 250, y = 200)
    
    ttbnedsa_ordinary = Button(ttbnedsaWindow, text = "Ordinary = ₱12.00", command = lambda:[tutuban_to_edsaordinary(), ttbnedsaWindow.destroy()],  width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_ordinary.place(x = 460, y = 200)
    

#defines tutuban/edsa/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaaircon():
    ttbnedsaairconWindow = Toplevel()
    ttbnedsaairconWindow.title("PNR Computing System")
    ttbnedsaairconWindow.geometry("900x500+300+200")
    ttbnedsaairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnedsaairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaairconWindow, text = "Yes", command = lambda:[ttbnedsadiscountaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaairconWindow, text = "No", command = lambda:[ttbnedsaregularaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/edsa/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnedsaregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
     
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban/edsa/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsadiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)        
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/edsa/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaordinary():
    ttbnedsaordinaryWindow = Toplevel()
    ttbnedsaordinaryWindow.title("PNR Computing System")
    ttbnedsaordinaryWindow.geometry("900x500+300+200")
    ttbnedsaordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnedsaordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaordinaryWindow, text = "Yes", command = lambda:[ttbnedsadiscountordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaordinaryWindow, text = "No", command = lambda:[ttbnedsaregularordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/edsa/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsaregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
        
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/edsa/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnedsadiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines tutuban to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_bicutaninput():
    ttbnbctnWindow = Toplevel()
    ttbnbctnWindow.title("PNR Computing System")
    ttbnbctnWindow.geometry("900x500+300+200")
    ttbnbctnWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnbctn_label = Label(ttbnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnbctn_label.place(x = 220, y = 110)
    
    ttbnbctn_aircon = Button(ttbnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[tutuban_to_bctaircon(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_aircon.place(x = 250, y = 200)
    
    ttbnbctn_ordinary = Button(ttbnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[tutuban_to_bctordinary(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_ordinary.place(x = 460, y = 200)

#defines tutuban/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_bctaircon():
    ttbnbctairconWindow = Toplevel()
    ttbnbctairconWindow.title("PNR Computing System")
    ttbnbctairconWindow.geometry("900x500+300+200")
    ttbnbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctairconWindow, text = "Yes", command = lambda:[ttbnbctdiscountaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctairconWindow, text = "No", command = lambda:[ttbnbctregularaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_bctordinary():
    ttbnbctordinaryWindow = Toplevel()
    ttbnbctordinaryWindow.title("PNR Computing System")
    ttbnbctordinaryWindow.geometry("900x500+300+200")
    ttbnbctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctordinaryWindow, text = "Yes", command = lambda:[ttbnbctdiscountordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctordinaryWindow, text = "No", command = lambda:[ttbnbctregularordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sucatinput():
    ttbnsctWindow = Toplevel()
    ttbnsctWindow.title("PNR Computing System")
    ttbnsctWindow.geometry("900x500+300+200")
    ttbnsctWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnsct_label = Label(ttbnsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnsct_label.place(x = 220, y = 110)
    
    ttbnsct_aircon = Button(ttbnsctWindow, text = "Aircon = ₱25.00", command = lambda:[tutuban_to_sctaircon(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_aircon.place(x = 250, y = 200)
    
    ttbnsct_ordinary = Button(ttbnsctWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_sctordinary(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_ordinary.place(x = 460, y = 200)

#defines tutuban/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_sctaircon():
    ttbnsctairconWindow = Toplevel()
    ttbnsctairconWindow.title("PNR Computing System")
    ttbnsctairconWindow.geometry("900x500+300+200")
    ttbnsctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(ttbnsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctairconWindow, text = "Yes", command = lambda:[ttbnsctdiscountaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctairconWindow, text = "No", command = lambda:[ttbnsctregularaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines tutuban/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sctordinary():
    ttbnsctordinaryWindow = Toplevel()
    ttbnsctordinaryWindow.title("PNR Computing System")
    ttbnsctordinaryWindow.geometry("900x500+300+200")
    ttbnsctordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctordinaryWindow, text = "Yes", command = lambda:[ttbnsctdiscountordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctordinaryWindow, text = "No", command = lambda:[ttbnsctregularordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
#defines tutuban to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_alabanginput():
    ttbnalbngWindow = Toplevel()
    ttbnalbngWindow.title("PNR Computing System")
    ttbnalbngWindow.geometry("900x500+300+200")
    ttbnalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnalbng_label = Label(ttbnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnalbng_label.place(x = 220, y = 110)
    
    ttbnalbng_aircon = Button(ttbnalbngWindow, text = "Aircon = ₱30.00", command = lambda:[tutuban_to_albngaircon(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_aircon.place(x = 250, y = 200)
    
    ttbnalbng_ordinary = Button(ttbnalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[tutuban_to_albngordinary(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_ordinary.place(x = 460, y = 200)
 
#defines tutuban/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_albngaircon():
    ttbnalbngairconWindow = Toplevel()
    ttbnalbngairconWindow.title("PNR Computing System")
    ttbnalbngairconWindow.geometry("900x500+300+200")
    ttbnalbngairconWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngairconWindow, text = "Yes", command = lambda:[ttbnalbngdiscountaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngairconWindow, text = "No", command = lambda:[ttbnalbngregularaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_albngordinary():
    ttbnalbngordinaryWindow = Toplevel()
    ttbnalbngordinaryWindow.title("PNR Computing System")
    ttbnalbngordinaryWindow.geometry("900x500+300+200")
    ttbnalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngordinaryWindow, text = "Yes", command = lambda:[ttbnalbngdiscountordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngordinaryWindow, text = "No", command = lambda:[ttbnalbngregularordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

    
#defines blumentritt destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def blumentritt_destination():
    newWindow4 = Toplevel()
    newWindow4.title("PNR Computing System - Blumentritt Station")
    newWindow4.geometry("900x500+300+200")
    newWindow4.resizable(width=False, height=False)
    mainLabel = Label(newWindow4, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow4, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blumentritt_sblabel = Label(newWindow4, text = "Blumentritt Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_sblabel.place(x = 460, y = 110)
    
    blumentritt_nblabel = Label(newWindow4, text = "Blumentritt Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_nblabel.place(x = 100, y = 110)
    
    blumentritt_tutubanbtn = Button(newWindow4, text = "Tutuban", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_tutubanbtn.place(x = 200, y = 170)
    
    blumentritt_laonlaanbtn = Button(newWindow4, text = "Laon-Laan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_laonlaanbtn.place(x = 480, y = 170)
    
    blumentritt_espanabtn = Button(newWindow4, text = "Espana", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_espanabtn.place(x = 480, y = 205)
    
    blumentritt_stamesabtn = Button(newWindow4, text = "Sta. Mesa", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_stamesabtn.place(x = 480, y = 240)
    
    blumentritt_pandacanbtn = Button(newWindow4, text = "Pandacan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pandacanbtn.place(x = 480, y = 275)
    
    blumentritt_pacobtn = Button(newWindow4, text = "Paco", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pacobtn.place(x = 480, y = 310)
    
    blumentritt_sanandresbtn = Button(newWindow4, text = "San Andres", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sanandresbtn.place(x = 480, y = 345)
    
    blumentritt_vitocruzbtn = Button(newWindow4, text = "Vito Cruz", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_vitocruzbtn.place(x = 480, y = 380)
    
    blumentritt_pasayrdbtn = Button(newWindow4, text = "Pasay Rd.", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pasayrdbtn.place(x = 630, y = 170)
    
    blumentritt_edsabtn = Button(newWindow4, text = "EDSA", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_edsabtn.place(x = 630, y = 205)
    
    blumentritt_nicholsbtn = Button(newWindow4, text = "Nichols", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_nicholsbtn.place(x = 630, y = 240)
    
    blumentritt_ftibtn = Button(newWindow4, text = "FTI", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_ftibtn.place(x = 630, y = 275)
    
    blumentritt_bicutanbtn = Button(newWindow4, text = "Bicutan", command = lambda:[blumentritt_to_bicutaninput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_bicutanbtn.place(x = 630, y = 310)
    
    blumentritt_sucatbtn = Button(newWindow4, text = "Sucat", command = lambda:[blumentritt_to_sucatinput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sucatbtn.place(x = 630, y = 345)
    
    blumentritt_alabangbtn = Button(newWindow4, text = "Alabang", command = lambda:[blumentritt_to_alabanginput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_alabangbtn.place(x = 630, y = 380)
    

    
    dateLabel = Label(newWindow4, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow4, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow4, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines blumentritt to fti as destination window 
#with labels, buttons, commands, functions, and UI design.   
def blumentritt_to_ftiinput():
    blmntrtftiWindow = Toplevel()
    blmntrtftiWindow.title("PNR Computing System")
    blmntrtftiWindow.geometry("900x500+300+200")
    blmntrtftiWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtfti_label = Label(blmntrtftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtfti_label.place(x = 220, y = 110)
    
    blmntrtfti_aircon = Button(blmntrtftiWindow, text = "Aircon = ₱15.00", command = lambda:[blumentritt_to_ftiaircon(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_aircon.place(x = 250, y = 200)
    
    blmntrtfti_ordinary = Button(blmntrtftiWindow, text = "Ordinary = ₱12.00", command = lambda:[blumentritt_to_ftiordinary(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_ordinary.place(x = 460, y = 200)

#defines blumentritt/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_ftiaircon():
    blmntrttftiairconWindow = Toplevel()
    blmntrttftiairconWindow .title("PNR Computing System")
    blmntrttftiairconWindow .geometry("900x500+300+200")
    blmntrttftiairconWindow .resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttftiairconWindow , text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiairconWindow , text = "Yes", command = lambda:[blmntrttftidiscountaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiairconWindow , text = "No", command = lambda:[blmntrttftiregularaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     

#defines blumentritt/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_ftiordinary():
    blmntrttftiordinaryWindow = Toplevel()
    blmntrttftiordinaryWindow.title("PNR Computing System")
    blmntrttftiordinaryWindow.geometry("900x500+300+200")
    blmntrttftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiordinaryWindow, text = "Yes", command = lambda:[blmntrttftidiscountordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiordinaryWindow, text = "No", command = lambda:[blmntrttftiregularordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design
def blmntrttftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bicutaninput():
    blmntrtbctnWindow = Toplevel()
    blmntrtbctnWindow.title("PNR Computing System")
    blmntrtbctnWindow.geometry("900x500+300+200")
    blmntrtbctnWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtbctn_label = Label(blmntrtbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtbctn_label.place(x = 220, y = 110)
    
    blmntrtbctn_aircon = Button(blmntrtbctnWindow, text = "Aircon = ₱20.00", command = lambda:[blumentritt_to_bctaircon(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_aircon.place(x = 250, y = 200)
    
    blmntrtbctn_ordinary = Button(blmntrtbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[blumentritt_to_bctordinary(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_ordinary.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_bctaircon():
    blmntrttbctairconWindow = Toplevel()
    blmntrttbctairconWindow.title("PNR Computing System")
    blmntrttbctairconWindow.geometry("900x500+300+200")
    blmntrttbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctairconWindow, text = "Yes", command = lambda:[blmntrttbctdiscountaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctairconWindow, text = "No", command = lambda:[blmntrttbctregularaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bctordinary():
    blmntrttbctordinaryWindow = Toplevel()
    blmntrttbctordinaryWindow.title("PNR Computing System")
    blmntrttbctordinaryWindow.geometry("900x500+300+200")
    blmntrttbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctordinaryWindow, text = "Yes", command = lambda:[blmntrttbctdiscountordinary(), blmntrttbcttordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctordinaryWindow, text = "No", command = lambda:[blmntrttbctregularordinary(), blmntrttbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
    
#defines blumentritt to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sucatinput():
    blmntrtsctWindow = Toplevel()
    blmntrtsctWindow.title("PNR Computing System")
    blmntrtsctWindow.geometry("900x500+300+200")
    blmntrtsctWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtsct_label = Label(blmntrtsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtsct_label.place(x = 220, y = 110)
    
    blmntrtsct_aircon = Button(blmntrtsctWindow, text = "Aircon = ₱25.00", command = lambda:[blumentritt_to_sctaircon(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_aircon.place(x = 250, y = 200)
    
    blmntrtsct_ordinary = Button(blmntrtsctWindow, text = "Ordinary = ₱20.00", command = lambda:[blumentritt_to_sctordinary(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_ordinary.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_sctaircon():
    blmntrttsctairconWindow = Toplevel()
    blmntrttsctairconWindow.title("PNR Computing System")
    blmntrttsctairconWindow.geometry("900x500+300+200")
    blmntrttsctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctairconWindow, text = "Yes", command = lambda:[blmntrttsctdiscountaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctairconWindow, text = "No", command = lambda:[blmntrttsctregularaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sctordinary():
    blmntrttsctordinaryWindow = Toplevel()
    blmntrttsctordinaryWindow.title("PNR Computing System")
    blmntrttsctordinaryWindow.geometry("900x500+300+200")
    blmntrttsctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctordinaryWindow, text = "Yes", command = lambda:[blmntrttsctdiscountordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctordinaryWindow, text = "No", command = lambda:[blmntrttsctregularordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines blumentritt to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_alabanginput():
    blmntrtalbngWindow = Toplevel()
    blmntrtalbngWindow.title("PNR Computing System")
    blmntrtalbngWindow.geometry("900x500+300+200")
    blmntrtalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtalbng_label = Label(blmntrtalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtalbng_label.place(x = 220, y = 110)
    
    blmntrtalbng_aircon = Button(blmntrtalbngWindow, text = "Aircon = ₱30.00", command = lambda:[blumentritt_to_albngaircon(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_aircon.place(x = 250, y = 200)
    
    blmntrtalbng_ordinary = Button(blmntrtalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[blumentritt_to_albngordinary(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_ordinary.place(x = 460, y = 200)

#defines blumentritt/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngaircon():
    blmntrttalbngairconWindow = Toplevel()
    blmntrttalbngairconWindow.title("PNR Computing System")
    blmntrttalbngairconWindow.geometry("900x500+300+200")
    blmntrttalbngairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(blmntrttalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngairconWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngairconWindow, text = "No", command = lambda:[blmntrttalbngregularaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)


#defines blumentritt/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines blumentritt/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngordinary():
    blmntrttalbngordinaryWindow = Toplevel()
    blmntrttalbngordinaryWindow.title("PNR Computing System")
    blmntrttalbngordinaryWindow.geometry("900x500+300+200")
    blmntrttalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngordinaryWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngordinaryWindow, text = "No", command = lambda:[blmntrttalbngregularordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laon laan destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def laonlaan_destination():
    newWindow5 = Toplevel()
    newWindow5.title("PNR Computing System - Laon-Laan Station")
    newWindow5.geometry("900x500+300+200")
    newWindow5.resizable(width=False, height=False)
    mainLabel = Label(newWindow5, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow5, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    laonlaan_sblabel = Label(newWindow5, text = "Laon-Laan Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_sblabel.place(x = 460, y = 110)
    
    laonlaan_nblabel = Label(newWindow5, text = "Laon-Laan Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_nblabel.place(x = 100, y = 110)
    
    laonlaan_tutubanbtn = Button(newWindow5, text = "Tutuban", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_tutubanbtn.place(x = 120, y = 170)
    
    laonlaan_blumentrittbtn = Button(newWindow5, text = "Blumentritt", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_blumentrittbtn.place(x = 270, y = 170)
    
    laonlaan_espanabtn = Button(newWindow5, text = "Espana", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_espanabtn.place(x = 480, y = 170)
    
    laonlaan_stamesabtn = Button(newWindow5, text = "Sta. Mesa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_stamesabtn.place(x = 480, y = 205)
    
    laonlaan_pandacanbtn = Button(newWindow5, text = "Pandacan", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pandacanbtn.place(x = 480, y = 240)
    
    laonlaan_pacobtn = Button(newWindow5, text = "Paco", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pacobtn.place(x = 480, y = 275)
    
    
    laonlaan_sanandresbtn = Button(newWindow5, text = "San Andres", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sanandresbtn.place(x = 480, y = 310)
    
    laonlaan_vitocruzbtn = Button(newWindow5, text = "Vito Cruz", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_vitocruzbtn.place(x = 480, y = 345 )
    
    
    laonlaan_delarosabtn = Button(newWindow5, text = "Dela Rosa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_delarosabtn.place(x = 480, y = 380)
    
    laonlaan_pasayrdbtn = Button(newWindow5, text = "Pasay Rd.", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pasayrdbtn.place(x = 630, y = 170)
    
    laonlaan_edsabtn = Button(newWindow5, text = "EDSA", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_edsabtn.place(x = 630, y = 205)
    
    laonlaan_nicholsbtn = Button(newWindow5, text = "Nichols", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_nicholsbtn.place(x = 630, y = 240)
    
    laonlaan_ftibtn = Button(newWindow5, text = "FTI", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_ftibtn.place(x = 630, y = 275)
    
    laonlaan_bicutanbtn = Button(newWindow5, text = "Bicutan", command = lambda:[laonlaan_to_bicutaninput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_bicutanbtn.place(x = 630, y = 310)
    
    laonlaan_sucatbtn = Button(newWindow5, text = "Sucat", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sucatbtn.place(x = 630, y = 345 )
    
    laonlaan_alabangbtn = Button(newWindow5, text = "Alabang", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_alabangbtn.place(x = 630, y = 380)
      
    
    dateLabel = Label(newWindow5, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow5, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow5, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines laonlaan to fti as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_ftiinput():
    lnlnftiWindow = Toplevel()
    lnlnftiWindow.title("PNR Computing System")
    lnlnftiWindow.geometry("900x500+300+200")
    lnlnftiWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnfti_label = Label(lnlnftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnfti_label.place(x = 220, y = 110)
    
    lnlnfti_aircon = Button(lnlnftiWindow, text = "Aircon = ₱15.00", width = 15, command = lambda:[laonlaan_to_ftiaircon(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_aircon.place(x = 250, y = 200)
    
    lnlnfti_ordinary = Button(lnlnftiWindow, text = "Ordinary = ₱12.00", width = 15, command = lambda:[laonlaan_to_ftiordinary(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_ordinary.place(x = 460, y = 200)

#defines laonlaan/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiaircon():
    laonlaanftiairconWindow = Toplevel()
    laonlaanftiairconWindow.title("PNR Computing System")
    laonlaanftiairconWindow.geometry("900x500+300+200")
    laonlaanftiairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanftiairconWindow, text = "Yes", command = lambda:[lnlnftidiscountaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanftiairconWindow, text = "No", command = lambda:[lnlnftiregularaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines laonlaan/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiordinary():
    lnlnftiordinaryWindow = Toplevel()
    lnlnftiordinaryWindow.title("PNR Computing System")
    lnlnftiordinaryWindow.geometry("900x500+300+200")
    lnlnftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnftiordinaryWindow, text = "Yes", command = lambda:[lnlnftidiscountordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnftiordinaryWindow, text = "No", command = lambda:[lnlnftiregularordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)
     
#defines laonlaan to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_bicutaninput():
    lnlnbctnWindow = Toplevel()
    lnlnbctnWindow.title("PNR Computing System")
    lnlnbctnWindow.geometry("900x500+300+200")
    lnlnbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnbctn_label = Label(lnlnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnbctn_label.place(x = 220, y = 110)
    
    lnlnbctn_aircon = Button(lnlnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[laonlaan_to_bctaircon(), lnlnbctnWindow.destroy()],width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_aircon.place(x = 250, y = 200)
    
    lnlnbctn_ordinary = Button(lnlnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[laonlaan_to_bctordinary(), lnlnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_ordinary.place(x = 460, y = 200)

#defines laonlaan/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctaircon():
    laonlaanbctairconWindow = Toplevel()
    laonlaanbctairconWindow.title("PNR Computing System")
    laonlaanbctairconWindow.geometry("900x500+300+200")
    laonlaanbctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanbctairconWindow, text = "Yes", command = lambda:[lnlnbctdiscountaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanbctairconWindow, text = "No", command = lambda:[lnlnbctregularaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines laonlaan/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctordinary():
    lnlnbctordinaryWindow = Toplevel()
    lnlnbctordinaryWindow.title("PNR Computing System")
    lnlnbctordinaryWindow.geometry("900x500+300+200")
    lnlnbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnbctordinaryWindow, text = "Yes", command = lambda:[lnlnbctdiscountordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnbctordinaryWindow, text = "No", command = lambda:[lnlnbctregularordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_alabanginput():
    lnlnalbngWindow = Toplevel()
    lnlnalbngWindow.title("PNR Computing System")
    lnlnalbngWindow.geometry("900x500+300+200")
    lnlnalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(lnlnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnalbng_label = Label(lnlnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnalbng_label.place(x = 220, y = 110)
    
    lnlnalbng_aircon = Button(lnlnalbngWindow, text = "Aircon = ₱25.00", command = lambda:[laonlaan_to_albngaircon(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_aircon.place(x = 250, y = 200)
    
    lnlnalbng_ordinary = Button(lnlnalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_albngordinary(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_ordinary.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngaircon():
    laonlaanalbngairconWindow = Toplevel()
    laonlaanalbngairconWindow.title("PNR Computing System")
    laonlaanalbngairconWindow.geometry("900x500+300+200")
    laonlaanalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(laonlaanalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(laonlaanalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanalbngairconWindow, text = "Yes", command = lambda:[lnlnalbngdiscountaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanalbngairconWindow, text = "No", command = lambda:[lnlnalbngregularaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngordinary():
    lnlnalbngordinaryWindow = Toplevel()
    lnlnalbngordinaryWindow.title("PNR Computing System")
    lnlnalbngordinaryWindow.geometry("900x500+300+200")
    lnlnalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnalbngordinaryWindow, text = "Yes", command = lambda:[lnlnalbngdiscountordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnalbngordinaryWindow, text = "No", command = lambda:[lnlnalbngregularordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana destination window with all the station buttons, commands, functions,
#current time and date, and UI design.   
def espana_destination():
    newWindow6 = Toplevel()
    newWindow6.title("PNR Computing System - España Station")
    newWindow6.geometry("900x500+300+200")
    newWindow6.resizable(width=False, height=False)
    mainLabel = Label(newWindow6, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow6, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    espana_sblabel = Label(newWindow6, text = "España Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_sblabel.place(x = 460, y = 110)
    
    espana_nblabel = Label(newWindow6, text = "España Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_nblabel.place(x = 100, y = 110)
    
    espana_tutubanbtn = Button(newWindow6, text = "Tutuban", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_tutubanbtn.place(x = 120, y = 170)
    
    espana_blumentrittbtn = Button(newWindow6, text = "Blumentritt", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_blumentrittbtn.place(x = 270, y = 170)
    
    espana_laonlaanbtn = Button(newWindow6, text = "Laon-Laan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_laonlaanbtn.place(x = 190, y = 205)
    
    espana_stamesabtn = Button(newWindow6, text = "Sta. Mesa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_stamesabtn.place(x = 480, y = 170)
    
    espana_pandacanbtn = Button(newWindow6, text = "Pandacan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pandacanbtn.place(x = 480, y = 205)
    
    espana_pacobtn = Button(newWindow6, text = "Paco", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pacobtn.place(x = 480, y = 240)
    
    espana_sanandreasbtn = Button(newWindow6, text = "San Andreas", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sanandreasbtn.place(x = 480, y = 275)
    
    espana_vitocruzbtn = Button(newWindow6, text = "Vito Cruz", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_vitocruzbtn.place(x = 480, y = 310)
    
    espana_delarosabtn = Button(newWindow6, text = "Dela Rosa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_delarosabtn.place(x = 480, y = 345)
    
    espana_pasayrdbtn = Button(newWindow6, text = "Pasay Rd.", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pasayrdbtn.place(x = 630, y = 170)
    
    espana_edsabtn = Button(newWindow6, text = "EDSA", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_edsabtn.place(x = 630, y = 205)
    
    espana_nicholsbtn = Button(newWindow6, text = "Nichols", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_nicholsbtn.place(x = 630, y = 240)
    
    espana_ftibtn = Button(newWindow6, text = "FTI", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_ftibtn.place(x = 630, y = 275)
    
    espana_bicutanbtn = Button(newWindow6, text = "Bicutan", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_bicutanbtn.place(x = 630, y = 310)
    
    espana_sucatbtn = Button(newWindow6, text = "Sucat", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sucatbtn.place(x = 630, y = 345)
    
    espana_alabangbtn = Button(newWindow6, text = "Alabang", command = lambda:[espana_to_alabanginput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_alabangbtn.place(x = 550, y = 380)
    
    
    dateLabel = Label(newWindow6, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow6, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow6, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines espana to fti as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiinput():
    espanaftiWindow = Toplevel()
    espanaftiWindow.title("PNR Computing System")
    espanaftiWindow.geometry("900x500+300+200")
    espanaftiWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanafti_label = Label(espanaftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanafti_label.place(x = 220, y = 110)
    
    espanafti_aircon = Button(espanaftiWindow, text = "Aircon = ₱15.00", command = lambda:[espana_to_ftiaircon(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_aircon.place(x = 250, y = 200)
    
    espanafti_ordinary = Button(espanaftiWindow, text = "Ordinary = ₱12.00", command = lambda:[espana_to_ftiordinary(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_ordinary.place(x = 460, y = 200)

#defines espana/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiaircon():
    espanaftiairconWindow = Toplevel()
    espanaftiairconWindow.title("PNR Computing System")
    espanaftiairconWindow.geometry("900x500+300+200")
    espanaftiairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiairconWindow, text = "Yes", command = lambda:[espanaftidiscountaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiairconWindow, text = "No", command = lambda:[espanaftiregularaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiordinary():
    espanaftiordinaryWindow = Toplevel()
    espanaftiordinaryWindow.title("PNR Computing System")
    espanaftiordinaryWindow.geometry("900x500+300+200")
    espanaftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiordinaryWindow, text = "Yes", command = lambda:[espanaftidiscountordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiordinaryWindow, text = "No", command = lambda:[espanaftiregularordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines espana to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def espana_to_sucatinput():
    espanasctWindow = Toplevel()
    espanasctWindow.title("PNR Computing System")
    espanasctWindow.geometry("900x500+300+200")
    espanasctWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanasct_label = Label(espanasctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanasct_label.place(x = 220, y = 110)
    
    espanasct_aircon = Button(espanasctWindow, text = "Aircon = ₱20.00", command = lambda:[espana_to_sucataircon(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_aircon.place(x = 250, y = 200)
    
    espanasct_ordinary = Button(espanasctWindow, text = "Ordinary = ₱16.00", command = lambda:[espana_to_sucatordinary(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_ordinary.place(x = 460, y = 200)

#defines espana/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucataircon():
    espanasctairconWindow = Toplevel()
    espanasctairconWindow.title("PNR Computing System")
    espanasctairconWindow.geometry("900x500+300+200")
    espanasctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(espanasctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctairconWindow, text = "Yes", command = lambda:[espanasctdiscountaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctairconWindow, text = "No", command = lambda:[espanasctregularaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucatordinary():
    espanasctordinaryWindow = Toplevel()
    espanasctordinaryWindow.title("PNR Computing System")
    espanasctordinaryWindow.geometry("900x500+300+200")
    espanasctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanasctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctordinaryWindow, text = "Yes", command = lambda:[espanasctdiscountordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctordinaryWindow, text = "No", command = lambda:[espanasctregularordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabanginput():
    espanaalbngWindow = Toplevel()
    espanaalbngWindow.title("PNR Computing System")
    espanaalbngWindow.geometry("900x500+300+200")
    espanaalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanaalbng_label = Label(espanaalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanaalbng_label.place(x = 220, y = 110)
    
    espanaalbng_aircon = Button(espanaalbngWindow, text = "Aircon = ₱25.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_aircon.place(x = 250, y = 200)
    
    espanaalbng_ordinary = Button(espanaalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_ordinary.place(x = 460, y = 200)

#defines espana/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangaircon():
    espanaalbngairconWindow = Toplevel()
    espanaalbngairconWindow.title("PNR Computing System")
    espanaalbngairconWindow.geometry("900x500+300+200")
    espanaalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngairconWindow, text = "Yes", command = lambda:[espanaalbngdiscountaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngairconWindow, text = "No", command = lambda:[espanaalbngregularaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangordinary():
    espanaalbngordinaryWindow = Toplevel()
    espanaalbngordinaryWindow.title("PNR Computing System")
    espanaalbngordinaryWindow.geometry("900x500+300+200")
    espanaalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngordinaryWindow, text = "Yes", command = lambda:[espanaalbngdiscountordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngordinaryWindow, text = "No", command = lambda:[espanaalbngregularordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)   

#defines sta.mesa destination window with all the station buttons, commands, functions,
#current time and date, and UI design.    
def stamesa_destination():
    newWindow7 = Toplevel()
    newWindow7.title("PNR Computing System - Sta. Mesa Station")
    newWindow7.geometry("900x500+300+200")
    newWindow7.resizable(width=False, height=False)
    mainLabel = Label(newWindow7, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow7, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    stamesa_sblabel = Label(newWindow7, text = "Sta. Mesa Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_sblabel.place(x = 460, y = 110)
    
    stamesa_nblabel = Label(newWindow7, text = "Sta. Mesa Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_nblabel.place(x = 100, y = 110)
    
    stamesa_tutubanbtn = Button(newWindow7, text = "Tutuban", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_tutubanbtn.place(x = 120, y = 170)
    
    stamesa_blumentrittbtn = Button(newWindow7, text = "Blumentritt", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_blumentrittbtn.place(x = 270, y = 170)
    
    
    stamesa_laonlaanbtn = Button(newWindow7, text = "Laon-Laan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_laonlaanbtn.place(x = 120, y = 205)
    
    stamesa_espanabtn = Button(newWindow7, text = "Espana", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_espanabtn.place(x = 270, y = 205)
    
    
    stamesa_pandacanbtn = Button(newWindow7, text = "Pandacan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pandacanbtn.place(x = 480, y = 170)
    
    stamesa_pacobtn = Button(newWindow7, text = "Paco", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pacobtn.place(x = 480, y = 205)
    
    stamesa_sanandresbtn = Button(newWindow7, text = "San Andres", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sanandresbtn.place(x = 480, y = 240)
    
    stamesa_vitocruzbtn = Button(newWindow7, text = "Vito Cruz", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_vitocruzbtn.place(x = 480, y = 275)
    
    stamesa_delarosabtn = Button(newWindow7, text = "Dela Rosa", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_delarosabtn.place(x = 480, y = 310)
    
    stamesa_pasayrdbtn = Button(newWindow7, text = "Pasay Rd.", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pasayrdbtn.place(x = 480, y = 345)
    
    stamesa_edsabtn = Button(newWindow7, text = "EDSA", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_edsabtn.place(x = 630, y = 170)
    
    stamesa_nicholsbtn = Button(newWindow7, text = "Nichols", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_nicholsbtn.place(x = 630, y = 205)
    
    stamesa_ftibtn = Button(newWindow7, text = "FTI", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_ftibtn.place(x = 630, y = 240)
    
    stamesa_bicutanbtn = Button(newWindow7, text = "Bicutan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_bicutanbtn.place(x = 630, y = 275)
    
    stamesa_sucatbtn = Button(newWindow7, text = "Sucat", command = lambda:[stamesa_to_sucatinput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sucatbtn.place(x = 630, y = 310)
    
    stamesa_alabangbtn = Button(newWindow7, text = "Alabang", command = lambda:[stamesa_to_alabanginput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_alabangbtn.place(x = 630, y = 345)
    
    
    dateLabel = Label(newWindow7, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow7, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow7, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
        

#defines sta.mesa to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutaninput():
    stmsbctnWindow = Toplevel()
    stmsbctnWindow.title("PNR Computing System")
    stmsbctnWindow.geometry("900x500+300+200")
    stmsbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsbctn_label = Label(stmsbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsbctn_label.place(x = 220, y = 110)
    
    stmsbctn_aircon = Button(stmsbctnWindow, text = "Aircon = ₱15.00", command = lambda:[stamesa_to_bicutanaircon(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_aircon.place(x = 250, y = 200)
    
    stmsbctn_ordinary = Button(stmsbctnWindow, text = "Ordinary = ₱12.00", command = lambda:[stamesa_to_bicutanordinary(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_bicutanaircon():
    stmsbctnairconWindow = Toplevel()
    stmsbctnairconWindow.title("PNR Computing System")
    stmsbctnairconWindow.geometry("900x500+300+200")
    stmsbctnairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsbctnairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsbctnairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnairconWindow, text = "Yes", command = lambda:[stamesabctndiscountaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnairconWindow, text = "No", command = lambda:[stamesabctnregularaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesabctndiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines sta.mesa/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutanordinary():
    stmsbctnordinaryWindow = Toplevel()
    stmsbctnordinaryWindow.title("PNR Computing System")
    stmsbctnordinaryWindow.geometry("900x500+300+200")
    stmsbctnordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsbctnordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnordinaryWindow, text = "Yes", command = lambda:[stamesabctndiscountordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnordinaryWindow, text = "No", command = lambda:[stamesabctnregularordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctndiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatinput():
    stmssctWindow = Toplevel()
    stmssctWindow.title("PNR Computing System")
    stmssctWindow.geometry("900x500+300+200")
    stmssctWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmssct_label = Label(stmssctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmssct_label.place(x = 220, y = 110)
    
    stmssct_aircon = Button(stmssctWindow, text = "Aircon = ₱20.00", command = lambda:[stamesa_to_sucataircon(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_aircon.place(x = 250, y = 200)
    
    stmssct_ordinary = Button(stmssctWindow, text = "Ordinary = ₱16.00", command = lambda:[stamesa_to_sucatordinary(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_ordinary.place(x = 460, y = 200)

#defines sta.mesa/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_sucataircon():
    stmssctairconWindow = Toplevel()
    stmssctairconWindow.title("PNR Computing System")
    stmssctairconWindow.geometry("900x500+300+200")
    stmssctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmssctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmssctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctairconWindow, text = "Yes", command = lambda:[stamesasctdiscountaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctairconWindow, text = "No", command = lambda:[stamesasctregularaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatordinary():
    stmssctordinaryWindow = Toplevel()
    stmssctordinaryWindow.title("PNR Computing System")
    stmssctordinaryWindow.geometry("900x500+300+200")
    stmssctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmssctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctordinaryWindow, text = "Yes", command = lambda:[stamesasctdiscountordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctordinaryWindow, text = "No", command = lambda:[stamesasctregularordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
    
#defines sta.mesa to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabanginput():
    stmsalbngWindow = Toplevel()
    stmsalbngWindow.title("PNR Computing System")
    stmsalbngWindow.geometry("900x500+300+200")
    stmsalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsalbng_label = Label(stmsalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsalbng_label.place(x = 220, y = 110)
    
    stmsalbng_aircon = Button(stmsalbngWindow, text = "Aircon = ₱25.00", command = lambda:[stamesa_to_alabangaircon(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_aircon.place(x = 250, y = 200)
    
    stmsalbng_ordinary = Button(stmsalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[stamesa_to_alabangordinary(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabangaircon():
    stmsalbngairconWindow = Toplevel()
    stmsalbngairconWindow.title("PNR Computing System")
    stmsalbngairconWindow.geometry("900x500+300+200")
    stmsalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngairconWindow, text = "Yes", command = lambda:[stamesaalbngdiscountaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngairconWindow, text = "No", command = lambda:[stamesaalbngregularaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_alabangordinary():
    stmsalbngordinaryWindow = Toplevel()
    stmsalbngordinaryWindow.title("PNR Computing System")
    stmsalbngordinaryWindow.geometry("900x500+300+200")
    stmsalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngordinaryWindow, text = "Yes", command = lambda:[stamesaalbngdiscountordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngordinaryWindow, text = "No", command = lambda:[stamesaalbngregularordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban station queueing window 
#with label, boolean expressions, button and UI design.
def ttbnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 1" in the queue
    passenger_queue_tutuban.append('User 1')
    
    if len(passenger_queue_tutuban) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_tutuban) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
#defines blumentritt station queueing window 
#with label, boolean expressions, button and UI design.        
def blmntrttqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 1" in the queue
    passenger_queue_blumentritt.append('User 1')
    if len(passenger_queue_blumentritt) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_blumentritt) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines laon-laan station queueing window 
#with label, boolean expressions, button and UI design.
def lnlnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 1" in the queue
    passenger_queue_laonlaan.append('User 1')
    if len(passenger_queue_laonlaan) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_laonlaan) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
                         
#defines espana station queueing window 
#with label, boolean expressions, button and UI design.
def espanaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 1" in the queue
    passenger_queue_espana.append('User 1')
    if len(passenger_queue_espana) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_espana) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines sta.mesa station queueing window 
#with label, boolean expressions, button and UI design.
def stamesaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 1" in the queue
    passenger_queue_stamesa.append('User 1')
    if len(passenger_queue_stamesa) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_stamesa) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)


#method to execute in running the window
root.mainloop()

#References:
#https://www.tutorialspoint.com/python-to-create-a-digital-clock-using-tkinter
#https://realpython.com/python-gui-tkinter/#:~:text=Python%20has%20a%20lot%20of,Windows%2C%20macOS%2C%20and%20Linux.
#https://discuss.codecademy.com/t/how-to-convert-to-12-hour-clock/3920/3
#https://stackoverflow.com/questions/2416486/how-to-create-a-password-entry-field-using-tkinter
#https://www.youtube.com/watch?v=c3rp-iKe3cI&ab_channel=GeeksforGeeks
# photo of pnr - https://en.wikipedia.org/wiki/PNR_8000_class
#https://stackoverflow.com/questions/39416021/border-for-tkinter-label
#https://www.youtube.com/watch?v=7A_csP9drJw&list=LL&index=1&t=260s&ab_channel=Codemy.com
#https://stackoverflow.com/questions/13865009/have-multiple-commands-when-button-is-pressed

# %% [markdown]
# #  User 2

# %%
#importing all the necessary module in building this app 
import tkinter
from tkinter.ttk import Button
import time
import tkinter as tk
from tkinter import *
import datetime as dt
import time as tm
from tkinter import ttk
from PIL import Image, ImageTk


#root window
root = Tk()
root.geometry('900x500+300+200')  
root.title("PNR - Computing Application")
root.resizable(width=False, height=False)

#main picture of PNR Computing System
image1 = Image.open("C:\\Users\\Nath\\Downloads\\PNR (2).png")
test = ImageTk.PhotoImage(image1)
imageLabel = tkinter.Label(image=test)
imageLabel.image = test
imageLabel.place(x=2, y=90)

#UI Design
mainLabel = Label(root, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
mainLabel.pack()
botLabel = Label(root, fg = "white", bg = "#FF8552", width = 150, height = 1)
botLabel.place(y=480)

#Welcome label, email label, and password label
welcomeLabel = Label(root, text = "\nHi! Welcome to PNR Computing System!", font=("Microsoft YaHei UI Bold", 11))
welcomeLabel.place(x = 480, y = 150)
inputLabel=Label(root, text="Please sign in using your email account.", font=("Microsoft YaHei UI Light", 9))
inputLabel.place(x = 500, y = 200)
emailLabel = Label(root, text = "Email:", font = ("Microsoft YaHei UI Light", 9))
emailLabel.place(x = 440, y = 228)
passLabel = Label(root, text = "Password:", font = ("Microsoft YaHei UI Light", 9))
passLabel.place(x = 430, y = 260)

#Email Input 
inputEmail= Entry(root, width= 30)
inputEmail.focus_set()
inputEmail.place(x = 500, y = 230) 
inputEmail.configure(bg = "white")

#Password Input
pass_value = StringVar
inputPass= Entry(root, width= 30, textvariable = pass_value, show = "\u2022")
inputPass.focus_set()
inputPass.place(x = 500, y = 260)
inputPass.configure(bg = "white")

#character limit for password
def character_limit(pass_value):
    if len(pass_value.get()) > 0:
        pass_value.set(pass_value.get()[-1])



#define a message after clicking an account 
def crtaccmessage():
    msg = Label(root, text = "Sorry! creating an account is not yet available.")
    msg.place(x = 490, y = 380)
    
    msg2 = Label(root, text = "Please press Next to proceed.")
    msg2.place(x = 490, y = 395)
    
#create account button    
crtaccbtn = Button (root, text = "Create an Account", command = crtaccmessage, width = 18, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
crtaccbtn.place(x = 490, y = 330)

#Date & Time
date = dt.datetime.now()

dateLabel = Label(root, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
dateLabel.place(x = 720, y = 50)

pstLabel = Label(root, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
pstLabel.place(x = 700, y = 30)


timeLabel = Label(root, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

def clock():
    text_input = time.strftime("%I:%M:%S %p")
    timeLabel.config(text=text_input)
    timeLabel.after(200, clock)
    timeLabel.place(x = 750, y = 70)
    
clock()

#define departure window
def DepartureWindow():
    root.destroy()
    newWindow2 = Tk()
    newWindow2.title("PNR Computing System - Departure List")
    newWindow2.geometry("900x500+300+200")
    newWindow2.resizable(width=False, height=False)
    

    #picture of Departure Point List
    image3 = Image.open("C:\\Users\\Nath\\Downloads\\pnr (8).png")
    test = ImageTk.PhotoImage(image3)
    imageLabel = tkinter.Label(image=test)
    imageLabel.image = test
    imageLabel.place(x=-160, y=-100)
    
    #UI design and departure label
    depFrame = Frame(newWindow2, bg = "white", width = 380, height = 430)
    depFrame.place(x = 500, y = 50)
    depLabel = Label(newWindow2, bg= "white", text = "Which station are you in?", font=("Microsoft YaHei UI Bold", 11))
    depLabel.place(x = 520, y = 150)
    depLabel2 = Label(newWindow2, bg= "white", text = "Choose your station by clicking the button below.", font=("Microsoft YaHei UI Light", 9))
    depLabel2.place(x = 520, y = 180)
    
    #tutuban button
    tutubanbtn = Button (newWindow2, text = "Tutuban", command = tutuban_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutubanbtn.place(x = 530, y = 220)
    blumentrittbtn = Button (newWindow2, text = "Blumentritt", command = blumentritt_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentrittbtn.place(x = 530, y = 270)
    
    #laon-laan button
    laon_laanbtn = Button (newWindow2, text = "Laon-Laan", command = laonlaan_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laon_laanbtn.place(x = 530, y = 320)
    
    #espana button
    espanabtn = Button (newWindow2, text = "España", command = espana_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espanabtn.place(x = 530, y = 370)
    
    #sta.mesa button
    sta_mesabtn = Button (newWindow2, text = "Sta. Mesa", command = stamesa_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    sta_mesabtn.place(x = 530, y = 420)
    
    #current date and time
    date = dt.datetime.now()
    dateLabel = Label(newWindow2, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 9), bg = "white")
    dateLabel.place(x = 720, y = 90)
    pstLabel = Label(newWindow2, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 9, 'bold'), bg = "white")
    pstLabel.place(x = 700, y = 70)
    timeLabel = Label(newWindow2, font=("Microsoft YaHei UI Light", 12, 'bold'), bg="white")
    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 110)
    clock()

    
#next button
nxtbtn = Button (root, text = "Next", command = DepartureWindow, width = 10, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
nxtbtn.place(x = 670, y = 330)


#defines tutuban destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def tutuban_destination():
    newWindow3 = Toplevel()
    newWindow3.title("PNR Computing System - Tutuban Station")
    newWindow3.geometry("900x500+300+200")
    newWindow3.resizable(width=False, height=False)
    
    mainLabel = Label(newWindow3, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow3, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    tutuban_label = Label(newWindow3, text = "Tutuban Southbound Destination List", width = 45, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 15))
    tutuban_label.place(x = 195, y = 110)
    
    tutuban_blumentrittbtn = Button(newWindow3, text = "Blumentritt", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_blumentrittbtn.place(x = 150, y = 180)
    
    tutuban_laonlaanbtn = Button(newWindow3, text = "Laon-Laan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_laonlaanbtn.place(x = 150, y = 215)
    
    tutuban_espanabtn = Button(newWindow3, text = "Espana", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_espanabtn.place(x = 150, y = 250)
    
    tutuban_stamesabtn = Button(newWindow3, text = "Sta. Mesa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_stamesabtn.place(x = 150, y = 285)
    
    tutuban_pandacanbtn = Button(newWindow3, text = "Pandacan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pandacanbtn.place(x = 300, y = 180)
    
    tutuban_pacobtn = Button(newWindow3, text = "Paco", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pacobtn.place(x = 300, y = 215)
    
    tutuban_sanandresbtn = Button(newWindow3, text = "San Andres", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sanandresbtn.place(x = 300, y = 250)
    
    tutuban_vitocruzbtn = Button(newWindow3, text = "Vito Cruz", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_vitocruzbtn.place(x = 300, y = 285)
    
    tutuban_delarosabtn = Button(newWindow3, text = "Dela Rosa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_delarosabtn.place(x = 450, y = 180)
    
    tutuban_pasayrdbtn = Button(newWindow3, text = "Pasay Rd.", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pasayrdbtn.place(x = 450, y = 215)
    
    tutuban_edsabtn = Button(newWindow3, text = "EDSA", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_edsabtn.place(x = 450, y = 250)
    
    tutuban_nicholsbtn = Button(newWindow3, text = "Nichols", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_nicholsbtn.place(x = 450, y = 285)
    
    tutuban_ftibtn = Button(newWindow3, text = "FTI", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_ftibtn.place(x = 600, y = 180)
    
    tutuban_bicutanbtn = Button(newWindow3, text = "Bicutan", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_bicutanbtn.place(x = 600, y = 215)
    
    tutuban_sucatbtn = Button(newWindow3, text = "Sucat", command = lambda:[tutuban_to_sucatinput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sucatbtn.place(x = 600, y = 250)
    
    tutuban_alabangbtn = Button(newWindow3, text = "Alabang", command = lambda:[tutuban_to_alabanginput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_alabangbtn.place(x = 600, y = 285)
    
    
    
    dateLabel = Label(newWindow3, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow3, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow3, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines tutuban to edsa as destination window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsainput():
    ttbnedsaWindow = Toplevel()
    ttbnedsaWindow.title("PNR Computing System")
    ttbnedsaWindow.geometry("900x500+300+200")
    ttbnedsaWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnedsa_label = Label(ttbnedsaWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnedsa_label.place(x = 220, y = 110)
    
    ttbnedsa_aircon = Button(ttbnedsaWindow, text = "Aircon = ₱15.00", command = lambda:[tutuban_to_edsaaircon(), ttbnedsaWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_aircon.place(x = 250, y = 200)
    
    ttbnedsa_ordinary = Button(ttbnedsaWindow, text = "Ordinary = ₱12.00", command = lambda:[tutuban_to_edsaordinary(), ttbnedsaWindow.destroy()],  width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_ordinary.place(x = 460, y = 200)
    

#defines tutuban/edsa/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaaircon():
    ttbnedsaairconWindow = Toplevel()
    ttbnedsaairconWindow.title("PNR Computing System")
    ttbnedsaairconWindow.geometry("900x500+300+200")
    ttbnedsaairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnedsaairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaairconWindow, text = "Yes", command = lambda:[ttbnedsadiscountaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaairconWindow, text = "No", command = lambda:[ttbnedsaregularaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/edsa/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnedsaregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
     
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban/edsa/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsadiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)        
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/edsa/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaordinary():
    ttbnedsaordinaryWindow = Toplevel()
    ttbnedsaordinaryWindow.title("PNR Computing System")
    ttbnedsaordinaryWindow.geometry("900x500+300+200")
    ttbnedsaordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnedsaordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaordinaryWindow, text = "Yes", command = lambda:[ttbnedsadiscountordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaordinaryWindow, text = "No", command = lambda:[ttbnedsaregularordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/edsa/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsaregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
        
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/edsa/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnedsadiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines tutuban to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_bicutaninput():
    ttbnbctnWindow = Toplevel()
    ttbnbctnWindow.title("PNR Computing System")
    ttbnbctnWindow.geometry("900x500+300+200")
    ttbnbctnWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnbctn_label = Label(ttbnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnbctn_label.place(x = 220, y = 110)
    
    ttbnbctn_aircon = Button(ttbnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[tutuban_to_bctaircon(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_aircon.place(x = 250, y = 200)
    
    ttbnbctn_ordinary = Button(ttbnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[tutuban_to_bctordinary(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_ordinary.place(x = 460, y = 200)

#defines tutuban/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_bctaircon():
    ttbnbctairconWindow = Toplevel()
    ttbnbctairconWindow.title("PNR Computing System")
    ttbnbctairconWindow.geometry("900x500+300+200")
    ttbnbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctairconWindow, text = "Yes", command = lambda:[ttbnbctdiscountaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctairconWindow, text = "No", command = lambda:[ttbnbctregularaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_bctordinary():
    ttbnbctordinaryWindow = Toplevel()
    ttbnbctordinaryWindow.title("PNR Computing System")
    ttbnbctordinaryWindow.geometry("900x500+300+200")
    ttbnbctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctordinaryWindow, text = "Yes", command = lambda:[ttbnbctdiscountordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctordinaryWindow, text = "No", command = lambda:[ttbnbctregularordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sucatinput():
    ttbnsctWindow = Toplevel()
    ttbnsctWindow.title("PNR Computing System")
    ttbnsctWindow.geometry("900x500+300+200")
    ttbnsctWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnsct_label = Label(ttbnsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnsct_label.place(x = 220, y = 110)
    
    ttbnsct_aircon = Button(ttbnsctWindow, text = "Aircon = ₱25.00", command = lambda:[tutuban_to_sctaircon(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_aircon.place(x = 250, y = 200)
    
    ttbnsct_ordinary = Button(ttbnsctWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_sctordinary(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_ordinary.place(x = 460, y = 200)

#defines tutuban/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_sctaircon():
    ttbnsctairconWindow = Toplevel()
    ttbnsctairconWindow.title("PNR Computing System")
    ttbnsctairconWindow.geometry("900x500+300+200")
    ttbnsctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(ttbnsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctairconWindow, text = "Yes", command = lambda:[ttbnsctdiscountaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctairconWindow, text = "No", command = lambda:[ttbnsctregularaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines tutuban/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sctordinary():
    ttbnsctordinaryWindow = Toplevel()
    ttbnsctordinaryWindow.title("PNR Computing System")
    ttbnsctordinaryWindow.geometry("900x500+300+200")
    ttbnsctordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctordinaryWindow, text = "Yes", command = lambda:[ttbnsctdiscountordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctordinaryWindow, text = "No", command = lambda:[ttbnsctregularordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
#defines tutuban to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_alabanginput():
    ttbnalbngWindow = Toplevel()
    ttbnalbngWindow.title("PNR Computing System")
    ttbnalbngWindow.geometry("900x500+300+200")
    ttbnalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnalbng_label = Label(ttbnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnalbng_label.place(x = 220, y = 110)
    
    ttbnalbng_aircon = Button(ttbnalbngWindow, text = "Aircon = ₱30.00", command = lambda:[tutuban_to_albngaircon(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_aircon.place(x = 250, y = 200)
    
    ttbnalbng_ordinary = Button(ttbnalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[tutuban_to_albngordinary(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_ordinary.place(x = 460, y = 200)
 
#defines tutuban/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_albngaircon():
    ttbnalbngairconWindow = Toplevel()
    ttbnalbngairconWindow.title("PNR Computing System")
    ttbnalbngairconWindow.geometry("900x500+300+200")
    ttbnalbngairconWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngairconWindow, text = "Yes", command = lambda:[ttbnalbngdiscountaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngairconWindow, text = "No", command = lambda:[ttbnalbngregularaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_albngordinary():
    ttbnalbngordinaryWindow = Toplevel()
    ttbnalbngordinaryWindow.title("PNR Computing System")
    ttbnalbngordinaryWindow.geometry("900x500+300+200")
    ttbnalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngordinaryWindow, text = "Yes", command = lambda:[ttbnalbngdiscountordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngordinaryWindow, text = "No", command = lambda:[ttbnalbngregularordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

    
#defines blumentritt destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def blumentritt_destination():
    newWindow4 = Toplevel()
    newWindow4.title("PNR Computing System - Blumentritt Station")
    newWindow4.geometry("900x500+300+200")
    newWindow4.resizable(width=False, height=False)
    mainLabel = Label(newWindow4, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow4, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blumentritt_sblabel = Label(newWindow4, text = "Blumentritt Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_sblabel.place(x = 460, y = 110)
    
    blumentritt_nblabel = Label(newWindow4, text = "Blumentritt Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_nblabel.place(x = 100, y = 110)
    
    blumentritt_tutubanbtn = Button(newWindow4, text = "Tutuban", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_tutubanbtn.place(x = 200, y = 170)
    
    blumentritt_laonlaanbtn = Button(newWindow4, text = "Laon-Laan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_laonlaanbtn.place(x = 480, y = 170)
    
    blumentritt_espanabtn = Button(newWindow4, text = "Espana", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_espanabtn.place(x = 480, y = 205)
    
    blumentritt_stamesabtn = Button(newWindow4, text = "Sta. Mesa", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_stamesabtn.place(x = 480, y = 240)
    
    blumentritt_pandacanbtn = Button(newWindow4, text = "Pandacan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pandacanbtn.place(x = 480, y = 275)
    
    blumentritt_pacobtn = Button(newWindow4, text = "Paco", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pacobtn.place(x = 480, y = 310)
    
    blumentritt_sanandresbtn = Button(newWindow4, text = "San Andres", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sanandresbtn.place(x = 480, y = 345)
    
    blumentritt_vitocruzbtn = Button(newWindow4, text = "Vito Cruz", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_vitocruzbtn.place(x = 480, y = 380)
    
    blumentritt_pasayrdbtn = Button(newWindow4, text = "Pasay Rd.", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pasayrdbtn.place(x = 630, y = 170)
    
    blumentritt_edsabtn = Button(newWindow4, text = "EDSA", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_edsabtn.place(x = 630, y = 205)
    
    blumentritt_nicholsbtn = Button(newWindow4, text = "Nichols", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_nicholsbtn.place(x = 630, y = 240)
    
    blumentritt_ftibtn = Button(newWindow4, text = "FTI", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_ftibtn.place(x = 630, y = 275)
    
    blumentritt_bicutanbtn = Button(newWindow4, text = "Bicutan", command = lambda:[blumentritt_to_bicutaninput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_bicutanbtn.place(x = 630, y = 310)
    
    blumentritt_sucatbtn = Button(newWindow4, text = "Sucat", command = lambda:[blumentritt_to_sucatinput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sucatbtn.place(x = 630, y = 345)
    
    blumentritt_alabangbtn = Button(newWindow4, text = "Alabang", command = lambda:[blumentritt_to_alabanginput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_alabangbtn.place(x = 630, y = 380)
    

    
    dateLabel = Label(newWindow4, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow4, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow4, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines blumentritt to fti as destination window 
#with labels, buttons, commands, functions, and UI design.   
def blumentritt_to_ftiinput():
    blmntrtftiWindow = Toplevel()
    blmntrtftiWindow.title("PNR Computing System")
    blmntrtftiWindow.geometry("900x500+300+200")
    blmntrtftiWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtfti_label = Label(blmntrtftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtfti_label.place(x = 220, y = 110)
    
    blmntrtfti_aircon = Button(blmntrtftiWindow, text = "Aircon = ₱15.00", command = lambda:[blumentritt_to_ftiaircon(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_aircon.place(x = 250, y = 200)
    
    blmntrtfti_ordinary = Button(blmntrtftiWindow, text = "Ordinary = ₱12.00", command = lambda:[blumentritt_to_ftiordinary(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_ordinary.place(x = 460, y = 200)

#defines blumentritt/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_ftiaircon():
    blmntrttftiairconWindow = Toplevel()
    blmntrttftiairconWindow .title("PNR Computing System")
    blmntrttftiairconWindow .geometry("900x500+300+200")
    blmntrttftiairconWindow .resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttftiairconWindow , text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiairconWindow , text = "Yes", command = lambda:[blmntrttftidiscountaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiairconWindow , text = "No", command = lambda:[blmntrttftiregularaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     

#defines blumentritt/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_ftiordinary():
    blmntrttftiordinaryWindow = Toplevel()
    blmntrttftiordinaryWindow.title("PNR Computing System")
    blmntrttftiordinaryWindow.geometry("900x500+300+200")
    blmntrttftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiordinaryWindow, text = "Yes", command = lambda:[blmntrttftidiscountordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiordinaryWindow, text = "No", command = lambda:[blmntrttftiregularordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design
def blmntrttftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bicutaninput():
    blmntrtbctnWindow = Toplevel()
    blmntrtbctnWindow.title("PNR Computing System")
    blmntrtbctnWindow.geometry("900x500+300+200")
    blmntrtbctnWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtbctn_label = Label(blmntrtbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtbctn_label.place(x = 220, y = 110)
    
    blmntrtbctn_aircon = Button(blmntrtbctnWindow, text = "Aircon = ₱20.00", command = lambda:[blumentritt_to_bctaircon(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_aircon.place(x = 250, y = 200)
    
    blmntrtbctn_ordinary = Button(blmntrtbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[blumentritt_to_bctordinary(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_ordinary.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_bctaircon():
    blmntrttbctairconWindow = Toplevel()
    blmntrttbctairconWindow.title("PNR Computing System")
    blmntrttbctairconWindow.geometry("900x500+300+200")
    blmntrttbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctairconWindow, text = "Yes", command = lambda:[blmntrttbctdiscountaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctairconWindow, text = "No", command = lambda:[blmntrttbctregularaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bctordinary():
    blmntrttbctordinaryWindow = Toplevel()
    blmntrttbctordinaryWindow.title("PNR Computing System")
    blmntrttbctordinaryWindow.geometry("900x500+300+200")
    blmntrttbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctordinaryWindow, text = "Yes", command = lambda:[blmntrttbctdiscountordinary(), blmntrttbcttordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctordinaryWindow, text = "No", command = lambda:[blmntrttbctregularordinary(), blmntrttbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
    
#defines blumentritt to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sucatinput():
    blmntrtsctWindow = Toplevel()
    blmntrtsctWindow.title("PNR Computing System")
    blmntrtsctWindow.geometry("900x500+300+200")
    blmntrtsctWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtsct_label = Label(blmntrtsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtsct_label.place(x = 220, y = 110)
    
    blmntrtsct_aircon = Button(blmntrtsctWindow, text = "Aircon = ₱25.00", command = lambda:[blumentritt_to_sctaircon(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_aircon.place(x = 250, y = 200)
    
    blmntrtsct_ordinary = Button(blmntrtsctWindow, text = "Ordinary = ₱20.00", command = lambda:[blumentritt_to_sctordinary(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_ordinary.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_sctaircon():
    blmntrttsctairconWindow = Toplevel()
    blmntrttsctairconWindow.title("PNR Computing System")
    blmntrttsctairconWindow.geometry("900x500+300+200")
    blmntrttsctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctairconWindow, text = "Yes", command = lambda:[blmntrttsctdiscountaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctairconWindow, text = "No", command = lambda:[blmntrttsctregularaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sctordinary():
    blmntrttsctordinaryWindow = Toplevel()
    blmntrttsctordinaryWindow.title("PNR Computing System")
    blmntrttsctordinaryWindow.geometry("900x500+300+200")
    blmntrttsctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctordinaryWindow, text = "Yes", command = lambda:[blmntrttsctdiscountordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctordinaryWindow, text = "No", command = lambda:[blmntrttsctregularordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines blumentritt to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_alabanginput():
    blmntrtalbngWindow = Toplevel()
    blmntrtalbngWindow.title("PNR Computing System")
    blmntrtalbngWindow.geometry("900x500+300+200")
    blmntrtalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtalbng_label = Label(blmntrtalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtalbng_label.place(x = 220, y = 110)
    
    blmntrtalbng_aircon = Button(blmntrtalbngWindow, text = "Aircon = ₱30.00", command = lambda:[blumentritt_to_albngaircon(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_aircon.place(x = 250, y = 200)
    
    blmntrtalbng_ordinary = Button(blmntrtalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[blumentritt_to_albngordinary(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_ordinary.place(x = 460, y = 200)

#defines blumentritt/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngaircon():
    blmntrttalbngairconWindow = Toplevel()
    blmntrttalbngairconWindow.title("PNR Computing System")
    blmntrttalbngairconWindow.geometry("900x500+300+200")
    blmntrttalbngairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(blmntrttalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngairconWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngairconWindow, text = "No", command = lambda:[blmntrttalbngregularaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)


#defines blumentritt/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines blumentritt/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngordinary():
    blmntrttalbngordinaryWindow = Toplevel()
    blmntrttalbngordinaryWindow.title("PNR Computing System")
    blmntrttalbngordinaryWindow.geometry("900x500+300+200")
    blmntrttalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngordinaryWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngordinaryWindow, text = "No", command = lambda:[blmntrttalbngregularordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laon laan destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def laonlaan_destination():
    newWindow5 = Toplevel()
    newWindow5.title("PNR Computing System - Laon-Laan Station")
    newWindow5.geometry("900x500+300+200")
    newWindow5.resizable(width=False, height=False)
    mainLabel = Label(newWindow5, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow5, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    laonlaan_sblabel = Label(newWindow5, text = "Laon-Laan Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_sblabel.place(x = 460, y = 110)
    
    laonlaan_nblabel = Label(newWindow5, text = "Laon-Laan Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_nblabel.place(x = 100, y = 110)
    
    laonlaan_tutubanbtn = Button(newWindow5, text = "Tutuban", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_tutubanbtn.place(x = 120, y = 170)
    
    laonlaan_blumentrittbtn = Button(newWindow5, text = "Blumentritt", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_blumentrittbtn.place(x = 270, y = 170)
    
    laonlaan_espanabtn = Button(newWindow5, text = "Espana", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_espanabtn.place(x = 480, y = 170)
    
    laonlaan_stamesabtn = Button(newWindow5, text = "Sta. Mesa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_stamesabtn.place(x = 480, y = 205)
    
    laonlaan_pandacanbtn = Button(newWindow5, text = "Pandacan", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pandacanbtn.place(x = 480, y = 240)
    
    laonlaan_pacobtn = Button(newWindow5, text = "Paco", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pacobtn.place(x = 480, y = 275)
    
    
    laonlaan_sanandresbtn = Button(newWindow5, text = "San Andres", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sanandresbtn.place(x = 480, y = 310)
    
    laonlaan_vitocruzbtn = Button(newWindow5, text = "Vito Cruz", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_vitocruzbtn.place(x = 480, y = 345 )
    
    
    laonlaan_delarosabtn = Button(newWindow5, text = "Dela Rosa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_delarosabtn.place(x = 480, y = 380)
    
    laonlaan_pasayrdbtn = Button(newWindow5, text = "Pasay Rd.", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pasayrdbtn.place(x = 630, y = 170)
    
    laonlaan_edsabtn = Button(newWindow5, text = "EDSA", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_edsabtn.place(x = 630, y = 205)
    
    laonlaan_nicholsbtn = Button(newWindow5, text = "Nichols", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_nicholsbtn.place(x = 630, y = 240)
    
    laonlaan_ftibtn = Button(newWindow5, text = "FTI", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_ftibtn.place(x = 630, y = 275)
    
    laonlaan_bicutanbtn = Button(newWindow5, text = "Bicutan", command = lambda:[laonlaan_to_bicutaninput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_bicutanbtn.place(x = 630, y = 310)
    
    laonlaan_sucatbtn = Button(newWindow5, text = "Sucat", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sucatbtn.place(x = 630, y = 345 )
    
    laonlaan_alabangbtn = Button(newWindow5, text = "Alabang", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_alabangbtn.place(x = 630, y = 380)
      
    
    dateLabel = Label(newWindow5, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow5, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow5, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines laonlaan to fti as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_ftiinput():
    lnlnftiWindow = Toplevel()
    lnlnftiWindow.title("PNR Computing System")
    lnlnftiWindow.geometry("900x500+300+200")
    lnlnftiWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnfti_label = Label(lnlnftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnfti_label.place(x = 220, y = 110)
    
    lnlnfti_aircon = Button(lnlnftiWindow, text = "Aircon = ₱15.00", width = 15, command = lambda:[laonlaan_to_ftiaircon(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_aircon.place(x = 250, y = 200)
    
    lnlnfti_ordinary = Button(lnlnftiWindow, text = "Ordinary = ₱12.00", width = 15, command = lambda:[laonlaan_to_ftiordinary(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_ordinary.place(x = 460, y = 200)

#defines laonlaan/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiaircon():
    laonlaanftiairconWindow = Toplevel()
    laonlaanftiairconWindow.title("PNR Computing System")
    laonlaanftiairconWindow.geometry("900x500+300+200")
    laonlaanftiairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanftiairconWindow, text = "Yes", command = lambda:[lnlnftidiscountaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanftiairconWindow, text = "No", command = lambda:[lnlnftiregularaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines laonlaan/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiordinary():
    lnlnftiordinaryWindow = Toplevel()
    lnlnftiordinaryWindow.title("PNR Computing System")
    lnlnftiordinaryWindow.geometry("900x500+300+200")
    lnlnftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnftiordinaryWindow, text = "Yes", command = lambda:[lnlnftidiscountordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnftiordinaryWindow, text = "No", command = lambda:[lnlnftiregularordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)
     
#defines laonlaan to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_bicutaninput():
    lnlnbctnWindow = Toplevel()
    lnlnbctnWindow.title("PNR Computing System")
    lnlnbctnWindow.geometry("900x500+300+200")
    lnlnbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnbctn_label = Label(lnlnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnbctn_label.place(x = 220, y = 110)
    
    lnlnbctn_aircon = Button(lnlnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[laonlaan_to_bctaircon(), lnlnbctnWindow.destroy()],width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_aircon.place(x = 250, y = 200)
    
    lnlnbctn_ordinary = Button(lnlnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[laonlaan_to_bctordinary(), lnlnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_ordinary.place(x = 460, y = 200)

#defines laonlaan/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctaircon():
    laonlaanbctairconWindow = Toplevel()
    laonlaanbctairconWindow.title("PNR Computing System")
    laonlaanbctairconWindow.geometry("900x500+300+200")
    laonlaanbctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanbctairconWindow, text = "Yes", command = lambda:[lnlnbctdiscountaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanbctairconWindow, text = "No", command = lambda:[lnlnbctregularaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines laonlaan/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctordinary():
    lnlnbctordinaryWindow = Toplevel()
    lnlnbctordinaryWindow.title("PNR Computing System")
    lnlnbctordinaryWindow.geometry("900x500+300+200")
    lnlnbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnbctordinaryWindow, text = "Yes", command = lambda:[lnlnbctdiscountordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnbctordinaryWindow, text = "No", command = lambda:[lnlnbctregularordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_alabanginput():
    lnlnalbngWindow = Toplevel()
    lnlnalbngWindow.title("PNR Computing System")
    lnlnalbngWindow.geometry("900x500+300+200")
    lnlnalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(lnlnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnalbng_label = Label(lnlnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnalbng_label.place(x = 220, y = 110)
    
    lnlnalbng_aircon = Button(lnlnalbngWindow, text = "Aircon = ₱25.00", command = lambda:[laonlaan_to_albngaircon(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_aircon.place(x = 250, y = 200)
    
    lnlnalbng_ordinary = Button(lnlnalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_albngordinary(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_ordinary.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngaircon():
    laonlaanalbngairconWindow = Toplevel()
    laonlaanalbngairconWindow.title("PNR Computing System")
    laonlaanalbngairconWindow.geometry("900x500+300+200")
    laonlaanalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(laonlaanalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(laonlaanalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanalbngairconWindow, text = "Yes", command = lambda:[lnlnalbngdiscountaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanalbngairconWindow, text = "No", command = lambda:[lnlnalbngregularaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngordinary():
    lnlnalbngordinaryWindow = Toplevel()
    lnlnalbngordinaryWindow.title("PNR Computing System")
    lnlnalbngordinaryWindow.geometry("900x500+300+200")
    lnlnalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnalbngordinaryWindow, text = "Yes", command = lambda:[lnlnalbngdiscountordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnalbngordinaryWindow, text = "No", command = lambda:[lnlnalbngregularordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana destination window with all the station buttons, commands, functions,
#current time and date, and UI design.   
def espana_destination():
    newWindow6 = Toplevel()
    newWindow6.title("PNR Computing System - España Station")
    newWindow6.geometry("900x500+300+200")
    newWindow6.resizable(width=False, height=False)
    mainLabel = Label(newWindow6, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow6, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    espana_sblabel = Label(newWindow6, text = "España Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_sblabel.place(x = 460, y = 110)
    
    espana_nblabel = Label(newWindow6, text = "España Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_nblabel.place(x = 100, y = 110)
    
    espana_tutubanbtn = Button(newWindow6, text = "Tutuban", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_tutubanbtn.place(x = 120, y = 170)
    
    espana_blumentrittbtn = Button(newWindow6, text = "Blumentritt", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_blumentrittbtn.place(x = 270, y = 170)
    
    espana_laonlaanbtn = Button(newWindow6, text = "Laon-Laan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_laonlaanbtn.place(x = 190, y = 205)
    
    espana_stamesabtn = Button(newWindow6, text = "Sta. Mesa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_stamesabtn.place(x = 480, y = 170)
    
    espana_pandacanbtn = Button(newWindow6, text = "Pandacan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pandacanbtn.place(x = 480, y = 205)
    
    espana_pacobtn = Button(newWindow6, text = "Paco", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pacobtn.place(x = 480, y = 240)
    
    espana_sanandreasbtn = Button(newWindow6, text = "San Andreas", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sanandreasbtn.place(x = 480, y = 275)
    
    espana_vitocruzbtn = Button(newWindow6, text = "Vito Cruz", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_vitocruzbtn.place(x = 480, y = 310)
    
    espana_delarosabtn = Button(newWindow6, text = "Dela Rosa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_delarosabtn.place(x = 480, y = 345)
    
    espana_pasayrdbtn = Button(newWindow6, text = "Pasay Rd.", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pasayrdbtn.place(x = 630, y = 170)
    
    espana_edsabtn = Button(newWindow6, text = "EDSA", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_edsabtn.place(x = 630, y = 205)
    
    espana_nicholsbtn = Button(newWindow6, text = "Nichols", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_nicholsbtn.place(x = 630, y = 240)
    
    espana_ftibtn = Button(newWindow6, text = "FTI", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_ftibtn.place(x = 630, y = 275)
    
    espana_bicutanbtn = Button(newWindow6, text = "Bicutan", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_bicutanbtn.place(x = 630, y = 310)
    
    espana_sucatbtn = Button(newWindow6, text = "Sucat", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sucatbtn.place(x = 630, y = 345)
    
    espana_alabangbtn = Button(newWindow6, text = "Alabang", command = lambda:[espana_to_alabanginput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_alabangbtn.place(x = 550, y = 380)
    
    
    dateLabel = Label(newWindow6, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow6, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow6, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines espana to fti as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiinput():
    espanaftiWindow = Toplevel()
    espanaftiWindow.title("PNR Computing System")
    espanaftiWindow.geometry("900x500+300+200")
    espanaftiWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanafti_label = Label(espanaftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanafti_label.place(x = 220, y = 110)
    
    espanafti_aircon = Button(espanaftiWindow, text = "Aircon = ₱15.00", command = lambda:[espana_to_ftiaircon(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_aircon.place(x = 250, y = 200)
    
    espanafti_ordinary = Button(espanaftiWindow, text = "Ordinary = ₱12.00", command = lambda:[espana_to_ftiordinary(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_ordinary.place(x = 460, y = 200)

#defines espana/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiaircon():
    espanaftiairconWindow = Toplevel()
    espanaftiairconWindow.title("PNR Computing System")
    espanaftiairconWindow.geometry("900x500+300+200")
    espanaftiairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiairconWindow, text = "Yes", command = lambda:[espanaftidiscountaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiairconWindow, text = "No", command = lambda:[espanaftiregularaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiordinary():
    espanaftiordinaryWindow = Toplevel()
    espanaftiordinaryWindow.title("PNR Computing System")
    espanaftiordinaryWindow.geometry("900x500+300+200")
    espanaftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiordinaryWindow, text = "Yes", command = lambda:[espanaftidiscountordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiordinaryWindow, text = "No", command = lambda:[espanaftiregularordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines espana to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def espana_to_sucatinput():
    espanasctWindow = Toplevel()
    espanasctWindow.title("PNR Computing System")
    espanasctWindow.geometry("900x500+300+200")
    espanasctWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanasct_label = Label(espanasctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanasct_label.place(x = 220, y = 110)
    
    espanasct_aircon = Button(espanasctWindow, text = "Aircon = ₱20.00", command = lambda:[espana_to_sucataircon(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_aircon.place(x = 250, y = 200)
    
    espanasct_ordinary = Button(espanasctWindow, text = "Ordinary = ₱16.00", command = lambda:[espana_to_sucatordinary(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_ordinary.place(x = 460, y = 200)

#defines espana/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucataircon():
    espanasctairconWindow = Toplevel()
    espanasctairconWindow.title("PNR Computing System")
    espanasctairconWindow.geometry("900x500+300+200")
    espanasctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(espanasctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctairconWindow, text = "Yes", command = lambda:[espanasctdiscountaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctairconWindow, text = "No", command = lambda:[espanasctregularaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucatordinary():
    espanasctordinaryWindow = Toplevel()
    espanasctordinaryWindow.title("PNR Computing System")
    espanasctordinaryWindow.geometry("900x500+300+200")
    espanasctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanasctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctordinaryWindow, text = "Yes", command = lambda:[espanasctdiscountordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctordinaryWindow, text = "No", command = lambda:[espanasctregularordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabanginput():
    espanaalbngWindow = Toplevel()
    espanaalbngWindow.title("PNR Computing System")
    espanaalbngWindow.geometry("900x500+300+200")
    espanaalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanaalbng_label = Label(espanaalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanaalbng_label.place(x = 220, y = 110)
    
    espanaalbng_aircon = Button(espanaalbngWindow, text = "Aircon = ₱25.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_aircon.place(x = 250, y = 200)
    
    espanaalbng_ordinary = Button(espanaalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_ordinary.place(x = 460, y = 200)

#defines espana/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangaircon():
    espanaalbngairconWindow = Toplevel()
    espanaalbngairconWindow.title("PNR Computing System")
    espanaalbngairconWindow.geometry("900x500+300+200")
    espanaalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngairconWindow, text = "Yes", command = lambda:[espanaalbngdiscountaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngairconWindow, text = "No", command = lambda:[espanaalbngregularaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangordinary():
    espanaalbngordinaryWindow = Toplevel()
    espanaalbngordinaryWindow.title("PNR Computing System")
    espanaalbngordinaryWindow.geometry("900x500+300+200")
    espanaalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngordinaryWindow, text = "Yes", command = lambda:[espanaalbngdiscountordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngordinaryWindow, text = "No", command = lambda:[espanaalbngregularordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)   

#defines sta.mesa destination window with all the station buttons, commands, functions,
#current time and date, and UI design.    
def stamesa_destination():
    newWindow7 = Toplevel()
    newWindow7.title("PNR Computing System - Sta. Mesa Station")
    newWindow7.geometry("900x500+300+200")
    newWindow7.resizable(width=False, height=False)
    mainLabel = Label(newWindow7, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow7, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    stamesa_sblabel = Label(newWindow7, text = "Sta. Mesa Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_sblabel.place(x = 460, y = 110)
    
    stamesa_nblabel = Label(newWindow7, text = "Sta. Mesa Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_nblabel.place(x = 100, y = 110)
    
    stamesa_tutubanbtn = Button(newWindow7, text = "Tutuban", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_tutubanbtn.place(x = 120, y = 170)
    
    stamesa_blumentrittbtn = Button(newWindow7, text = "Blumentritt", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_blumentrittbtn.place(x = 270, y = 170)
    
    
    stamesa_laonlaanbtn = Button(newWindow7, text = "Laon-Laan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_laonlaanbtn.place(x = 120, y = 205)
    
    stamesa_espanabtn = Button(newWindow7, text = "Espana", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_espanabtn.place(x = 270, y = 205)
    
    
    stamesa_pandacanbtn = Button(newWindow7, text = "Pandacan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pandacanbtn.place(x = 480, y = 170)
    
    stamesa_pacobtn = Button(newWindow7, text = "Paco", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pacobtn.place(x = 480, y = 205)
    
    stamesa_sanandresbtn = Button(newWindow7, text = "San Andres", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sanandresbtn.place(x = 480, y = 240)
    
    stamesa_vitocruzbtn = Button(newWindow7, text = "Vito Cruz", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_vitocruzbtn.place(x = 480, y = 275)
    
    stamesa_delarosabtn = Button(newWindow7, text = "Dela Rosa", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_delarosabtn.place(x = 480, y = 310)
    
    stamesa_pasayrdbtn = Button(newWindow7, text = "Pasay Rd.", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pasayrdbtn.place(x = 480, y = 345)
    
    stamesa_edsabtn = Button(newWindow7, text = "EDSA", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_edsabtn.place(x = 630, y = 170)
    
    stamesa_nicholsbtn = Button(newWindow7, text = "Nichols", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_nicholsbtn.place(x = 630, y = 205)
    
    stamesa_ftibtn = Button(newWindow7, text = "FTI", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_ftibtn.place(x = 630, y = 240)
    
    stamesa_bicutanbtn = Button(newWindow7, text = "Bicutan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_bicutanbtn.place(x = 630, y = 275)
    
    stamesa_sucatbtn = Button(newWindow7, text = "Sucat", command = lambda:[stamesa_to_sucatinput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sucatbtn.place(x = 630, y = 310)
    
    stamesa_alabangbtn = Button(newWindow7, text = "Alabang", command = lambda:[stamesa_to_alabanginput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_alabangbtn.place(x = 630, y = 345)
    
    
    dateLabel = Label(newWindow7, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow7, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow7, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
        

#defines sta.mesa to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutaninput():
    stmsbctnWindow = Toplevel()
    stmsbctnWindow.title("PNR Computing System")
    stmsbctnWindow.geometry("900x500+300+200")
    stmsbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsbctn_label = Label(stmsbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsbctn_label.place(x = 220, y = 110)
    
    stmsbctn_aircon = Button(stmsbctnWindow, text = "Aircon = ₱15.00", command = lambda:[stamesa_to_bicutanaircon(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_aircon.place(x = 250, y = 200)
    
    stmsbctn_ordinary = Button(stmsbctnWindow, text = "Ordinary = ₱12.00", command = lambda:[stamesa_to_bicutanordinary(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_bicutanaircon():
    stmsbctnairconWindow = Toplevel()
    stmsbctnairconWindow.title("PNR Computing System")
    stmsbctnairconWindow.geometry("900x500+300+200")
    stmsbctnairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsbctnairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsbctnairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnairconWindow, text = "Yes", command = lambda:[stamesabctndiscountaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnairconWindow, text = "No", command = lambda:[stamesabctnregularaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesabctndiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines sta.mesa/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutanordinary():
    stmsbctnordinaryWindow = Toplevel()
    stmsbctnordinaryWindow.title("PNR Computing System")
    stmsbctnordinaryWindow.geometry("900x500+300+200")
    stmsbctnordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsbctnordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnordinaryWindow, text = "Yes", command = lambda:[stamesabctndiscountordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnordinaryWindow, text = "No", command = lambda:[stamesabctnregularordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctndiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatinput():
    stmssctWindow = Toplevel()
    stmssctWindow.title("PNR Computing System")
    stmssctWindow.geometry("900x500+300+200")
    stmssctWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmssct_label = Label(stmssctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmssct_label.place(x = 220, y = 110)
    
    stmssct_aircon = Button(stmssctWindow, text = "Aircon = ₱20.00", command = lambda:[stamesa_to_sucataircon(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_aircon.place(x = 250, y = 200)
    
    stmssct_ordinary = Button(stmssctWindow, text = "Ordinary = ₱16.00", command = lambda:[stamesa_to_sucatordinary(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_ordinary.place(x = 460, y = 200)

#defines sta.mesa/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_sucataircon():
    stmssctairconWindow = Toplevel()
    stmssctairconWindow.title("PNR Computing System")
    stmssctairconWindow.geometry("900x500+300+200")
    stmssctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmssctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmssctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctairconWindow, text = "Yes", command = lambda:[stamesasctdiscountaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctairconWindow, text = "No", command = lambda:[stamesasctregularaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatordinary():
    stmssctordinaryWindow = Toplevel()
    stmssctordinaryWindow.title("PNR Computing System")
    stmssctordinaryWindow.geometry("900x500+300+200")
    stmssctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmssctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctordinaryWindow, text = "Yes", command = lambda:[stamesasctdiscountordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctordinaryWindow, text = "No", command = lambda:[stamesasctregularordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
    
#defines sta.mesa to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabanginput():
    stmsalbngWindow = Toplevel()
    stmsalbngWindow.title("PNR Computing System")
    stmsalbngWindow.geometry("900x500+300+200")
    stmsalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsalbng_label = Label(stmsalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsalbng_label.place(x = 220, y = 110)
    
    stmsalbng_aircon = Button(stmsalbngWindow, text = "Aircon = ₱25.00", command = lambda:[stamesa_to_alabangaircon(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_aircon.place(x = 250, y = 200)
    
    stmsalbng_ordinary = Button(stmsalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[stamesa_to_alabangordinary(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabangaircon():
    stmsalbngairconWindow = Toplevel()
    stmsalbngairconWindow.title("PNR Computing System")
    stmsalbngairconWindow.geometry("900x500+300+200")
    stmsalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngairconWindow, text = "Yes", command = lambda:[stamesaalbngdiscountaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngairconWindow, text = "No", command = lambda:[stamesaalbngregularaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_alabangordinary():
    stmsalbngordinaryWindow = Toplevel()
    stmsalbngordinaryWindow.title("PNR Computing System")
    stmsalbngordinaryWindow.geometry("900x500+300+200")
    stmsalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngordinaryWindow, text = "Yes", command = lambda:[stamesaalbngdiscountordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngordinaryWindow, text = "No", command = lambda:[stamesaalbngregularordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban station queueing window 
#with label, boolean expressions, button and UI design.
def ttbnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 2" in the queue
    passenger_queue_tutuban.append('User 2')
    
    if len(passenger_queue_tutuban) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_tutuban) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
#defines blumentritt station queueing window 
#with label, boolean expressions, button and UI design.        
def blmntrttqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 2" in the queue
    passenger_queue_blumentritt.append('User 2')
    if len(passenger_queue_blumentritt) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_blumentritt) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines laon-laan station queueing window 
#with label, boolean expressions, button and UI design.
def lnlnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 2" in the queue
    passenger_queue_laonlaan.append('User 2')
    if len(passenger_queue_laonlaan) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_laonlaan) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
                         
#defines espana station queueing window 
#with label, boolean expressions, button and UI design.
def espanaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 2" in the queue
    passenger_queue_espana.append('User 2')
    if len(passenger_queue_espana) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_espana) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines sta.mesa station queueing window 
#with label, boolean expressions, button and UI design.
def stamesaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 2" in the queue
    passenger_queue_stamesa.append('User 2')
    if len(passenger_queue_stamesa) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_stamesa) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)


#method to execute in running the window
root.mainloop()

#References:
#https://www.tutorialspoint.com/python-to-create-a-digital-clock-using-tkinter
#https://realpython.com/python-gui-tkinter/#:~:text=Python%20has%20a%20lot%20of,Windows%2C%20macOS%2C%20and%20Linux.
#https://discuss.codecademy.com/t/how-to-convert-to-12-hour-clock/3920/3
#https://stackoverflow.com/questions/2416486/how-to-create-a-password-entry-field-using-tkinter
#https://www.youtube.com/watch?v=c3rp-iKe3cI&ab_channel=GeeksforGeeks
# photo of pnr - https://en.wikipedia.org/wiki/PNR_8000_class
#https://stackoverflow.com/questions/39416021/border-for-tkinter-label
#https://www.youtube.com/watch?v=7A_csP9drJw&list=LL&index=1&t=260s&ab_channel=Codemy.com
#https://stackoverflow.com/questions/13865009/have-multiple-commands-when-button-is-pressed

# %% [markdown]
# # User 3

# %%
#importing all the necessary module in building this app 
import tkinter
from tkinter.ttk import Button
import time
import tkinter as tk
from tkinter import *
import datetime as dt
import time as tm
from tkinter import ttk
from PIL import Image, ImageTk


#root window
root = Tk()
root.geometry('900x500+300+200')  
root.title("PNR - Computing Application")
root.resizable(width=False, height=False)

#main picture of PNR Computing System
image1 = Image.open("C:\\Users\\Nath\\Downloads\\PNR (2).png")
test = ImageTk.PhotoImage(image1)
imageLabel = tkinter.Label(image=test)
imageLabel.image = test
imageLabel.place(x=2, y=90)

#UI Design
mainLabel = Label(root, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
mainLabel.pack()
botLabel = Label(root, fg = "white", bg = "#FF8552", width = 150, height = 1)
botLabel.place(y=480)

#Welcome label, email label, and password label
welcomeLabel = Label(root, text = "\nHi! Welcome to PNR Computing System!", font=("Microsoft YaHei UI Bold", 11))
welcomeLabel.place(x = 480, y = 150)
inputLabel=Label(root, text="Please sign in using your email account.", font=("Microsoft YaHei UI Light", 9))
inputLabel.place(x = 500, y = 200)
emailLabel = Label(root, text = "Email:", font = ("Microsoft YaHei UI Light", 9))
emailLabel.place(x = 440, y = 228)
passLabel = Label(root, text = "Password:", font = ("Microsoft YaHei UI Light", 9))
passLabel.place(x = 430, y = 260)

#Email Input 
inputEmail= Entry(root, width= 30)
inputEmail.focus_set()
inputEmail.place(x = 500, y = 230) 
inputEmail.configure(bg = "white")

#Password Input
pass_value = StringVar
inputPass= Entry(root, width= 30, textvariable = pass_value, show = "\u2022")
inputPass.focus_set()
inputPass.place(x = 500, y = 260)
inputPass.configure(bg = "white")

#character limit for password
def character_limit(pass_value):
    if len(pass_value.get()) > 0:
        pass_value.set(pass_value.get()[-1])



#define a message after clicking an account 
def crtaccmessage():
    msg = Label(root, text = "Sorry! creating an account is not yet available.")
    msg.place(x = 490, y = 380)
    
    msg2 = Label(root, text = "Please press Next to proceed.")
    msg2.place(x = 490, y = 395)
    
#create account button    
crtaccbtn = Button (root, text = "Create an Account", command = crtaccmessage, width = 18, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
crtaccbtn.place(x = 490, y = 330)

#Date & Time
date = dt.datetime.now()

dateLabel = Label(root, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
dateLabel.place(x = 720, y = 50)

pstLabel = Label(root, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
pstLabel.place(x = 700, y = 30)


timeLabel = Label(root, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

def clock():
    text_input = time.strftime("%I:%M:%S %p")
    timeLabel.config(text=text_input)
    timeLabel.after(200, clock)
    timeLabel.place(x = 750, y = 70)
    
clock()

#define departure window
def DepartureWindow():
    root.destroy()
    newWindow2 = Tk()
    newWindow2.title("PNR Computing System - Departure List")
    newWindow2.geometry("900x500+300+200")
    newWindow2.resizable(width=False, height=False)
    

    #picture of Departure Point List
    image3 = Image.open("C:\\Users\\Nath\\Downloads\\pnr (8).png")
    test = ImageTk.PhotoImage(image3)
    imageLabel = tkinter.Label(image=test)
    imageLabel.image = test
    imageLabel.place(x=-160, y=-100)
    
    #UI design and departure label
    depFrame = Frame(newWindow2, bg = "white", width = 380, height = 430)
    depFrame.place(x = 500, y = 50)
    depLabel = Label(newWindow2, bg= "white", text = "Which station are you in?", font=("Microsoft YaHei UI Bold", 11))
    depLabel.place(x = 520, y = 150)
    depLabel2 = Label(newWindow2, bg= "white", text = "Choose your station by clicking the button below.", font=("Microsoft YaHei UI Light", 9))
    depLabel2.place(x = 520, y = 180)
    
    #tutuban button
    tutubanbtn = Button (newWindow2, text = "Tutuban", command = tutuban_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutubanbtn.place(x = 530, y = 220)
    blumentrittbtn = Button (newWindow2, text = "Blumentritt", command = blumentritt_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentrittbtn.place(x = 530, y = 270)
    
    #laon-laan button
    laon_laanbtn = Button (newWindow2, text = "Laon-Laan", command = laonlaan_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laon_laanbtn.place(x = 530, y = 320)
    
    #espana button
    espanabtn = Button (newWindow2, text = "España", command = espana_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espanabtn.place(x = 530, y = 370)
    
    #sta.mesa button
    sta_mesabtn = Button (newWindow2, text = "Sta. Mesa", command = stamesa_destination, width = 40, height = 2, borderwidth = 2, relief = "solid", bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    sta_mesabtn.place(x = 530, y = 420)
    
    #current date and time
    date = dt.datetime.now()
    dateLabel = Label(newWindow2, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 9), bg = "white")
    dateLabel.place(x = 720, y = 90)
    pstLabel = Label(newWindow2, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 9, 'bold'), bg = "white")
    pstLabel.place(x = 700, y = 70)
    timeLabel = Label(newWindow2, font=("Microsoft YaHei UI Light", 12, 'bold'), bg="white")
    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 110)
    clock()

    
#next button
nxtbtn = Button (root, text = "Next", command = DepartureWindow, width = 10, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
nxtbtn.place(x = 670, y = 330)


#defines tutuban destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def tutuban_destination():
    newWindow3 = Toplevel()
    newWindow3.title("PNR Computing System - Tutuban Station")
    newWindow3.geometry("900x500+300+200")
    newWindow3.resizable(width=False, height=False)
    
    mainLabel = Label(newWindow3, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow3, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    tutuban_label = Label(newWindow3, text = "Tutuban Southbound Destination List", width = 45, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 15))
    tutuban_label.place(x = 195, y = 110)
    
    tutuban_blumentrittbtn = Button(newWindow3, text = "Blumentritt", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_blumentrittbtn.place(x = 150, y = 180)
    
    tutuban_laonlaanbtn = Button(newWindow3, text = "Laon-Laan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_laonlaanbtn.place(x = 150, y = 215)
    
    tutuban_espanabtn = Button(newWindow3, text = "Espana", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_espanabtn.place(x = 150, y = 250)
    
    tutuban_stamesabtn = Button(newWindow3, text = "Sta. Mesa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_stamesabtn.place(x = 150, y = 285)
    
    tutuban_pandacanbtn = Button(newWindow3, text = "Pandacan", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pandacanbtn.place(x = 300, y = 180)
    
    tutuban_pacobtn = Button(newWindow3, text = "Paco", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pacobtn.place(x = 300, y = 215)
    
    tutuban_sanandresbtn = Button(newWindow3, text = "San Andres", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sanandresbtn.place(x = 300, y = 250)
    
    tutuban_vitocruzbtn = Button(newWindow3, text = "Vito Cruz", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_vitocruzbtn.place(x = 300, y = 285)
    
    tutuban_delarosabtn = Button(newWindow3, text = "Dela Rosa", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_delarosabtn.place(x = 450, y = 180)
    
    tutuban_pasayrdbtn = Button(newWindow3, text = "Pasay Rd.", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_pasayrdbtn.place(x = 450, y = 215)
    
    tutuban_edsabtn = Button(newWindow3, text = "EDSA", command = lambda:[tutuban_to_edsainput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_edsabtn.place(x = 450, y = 250)
    
    tutuban_nicholsbtn = Button(newWindow3, text = "Nichols", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_nicholsbtn.place(x = 450, y = 285)
    
    tutuban_ftibtn = Button(newWindow3, text = "FTI", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_ftibtn.place(x = 600, y = 180)
    
    tutuban_bicutanbtn = Button(newWindow3, text = "Bicutan", command = lambda:[tutuban_to_bicutaninput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_bicutanbtn.place(x = 600, y = 215)
    
    tutuban_sucatbtn = Button(newWindow3, text = "Sucat", command = lambda:[tutuban_to_sucatinput(), newWindow3.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_sucatbtn.place(x = 600, y = 250)
    
    tutuban_alabangbtn = Button(newWindow3, text = "Alabang", command = lambda:[tutuban_to_alabanginput(), newWindow3.destroy()],  width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    tutuban_alabangbtn.place(x = 600, y = 285)
    
    
    
    dateLabel = Label(newWindow3, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow3, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow3, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines tutuban to edsa as destination window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsainput():
    ttbnedsaWindow = Toplevel()
    ttbnedsaWindow.title("PNR Computing System")
    ttbnedsaWindow.geometry("900x500+300+200")
    ttbnedsaWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnedsa_label = Label(ttbnedsaWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnedsa_label.place(x = 220, y = 110)
    
    ttbnedsa_aircon = Button(ttbnedsaWindow, text = "Aircon = ₱15.00", command = lambda:[tutuban_to_edsaaircon(), ttbnedsaWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_aircon.place(x = 250, y = 200)
    
    ttbnedsa_ordinary = Button(ttbnedsaWindow, text = "Ordinary = ₱12.00", command = lambda:[tutuban_to_edsaordinary(), ttbnedsaWindow.destroy()],  width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnedsa_ordinary.place(x = 460, y = 200)
    

#defines tutuban/edsa/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaaircon():
    ttbnedsaairconWindow = Toplevel()
    ttbnedsaairconWindow.title("PNR Computing System")
    ttbnedsaairconWindow.geometry("900x500+300+200")
    ttbnedsaairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnedsaairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaairconWindow, text = "Yes", command = lambda:[ttbnedsadiscountaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaairconWindow, text = "No", command = lambda:[ttbnedsaregularaircon(), ttbnedsaairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/edsa/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnedsaregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
     
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban/edsa/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsadiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)        
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/edsa/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_edsaordinary():
    ttbnedsaordinaryWindow = Toplevel()
    ttbnedsaordinaryWindow.title("PNR Computing System")
    ttbnedsaordinaryWindow.geometry("900x500+300+200")
    ttbnedsaordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnedsaordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnedsaordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnedsaordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnedsaordinaryWindow, text = "Yes", command = lambda:[ttbnedsadiscountordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnedsaordinaryWindow, text = "No", command = lambda:[ttbnedsaregularordinary(), ttbnedsaordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/edsa/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnedsaregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
        
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/edsa/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnedsadiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines tutuban to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_bicutaninput():
    ttbnbctnWindow = Toplevel()
    ttbnbctnWindow.title("PNR Computing System")
    ttbnbctnWindow.geometry("900x500+300+200")
    ttbnbctnWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    ttbnbctn_label = Label(ttbnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnbctn_label.place(x = 220, y = 110)
    
    ttbnbctn_aircon = Button(ttbnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[tutuban_to_bctaircon(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_aircon.place(x = 250, y = 200)
    
    ttbnbctn_ordinary = Button(ttbnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[tutuban_to_bctordinary(), ttbnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnbctn_ordinary.place(x = 460, y = 200)

#defines tutuban/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_bctaircon():
    ttbnbctairconWindow = Toplevel()
    ttbnbctairconWindow.title("PNR Computing System")
    ttbnbctairconWindow.geometry("900x500+300+200")
    ttbnbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctairconWindow, text = "Yes", command = lambda:[ttbnbctdiscountaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctairconWindow, text = "No", command = lambda:[ttbnbctregularaircon(), ttbnbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
        
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def tutuban_to_bctordinary():
    ttbnbctordinaryWindow = Toplevel()
    ttbnbctordinaryWindow.title("PNR Computing System")
    ttbnbctordinaryWindow.geometry("900x500+300+200")
    ttbnbctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnbctordinaryWindow, text = "Yes", command = lambda:[ttbnbctdiscountordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnbctordinaryWindow, text = "No", command = lambda:[ttbnbctregularordinary(), ttbnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sucatinput():
    ttbnsctWindow = Toplevel()
    ttbnsctWindow.title("PNR Computing System")
    ttbnsctWindow.geometry("900x500+300+200")
    ttbnsctWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnsct_label = Label(ttbnsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnsct_label.place(x = 220, y = 110)
    
    ttbnsct_aircon = Button(ttbnsctWindow, text = "Aircon = ₱25.00", command = lambda:[tutuban_to_sctaircon(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_aircon.place(x = 250, y = 200)
    
    ttbnsct_ordinary = Button(ttbnsctWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_sctordinary(), ttbnsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnsct_ordinary.place(x = 460, y = 200)

#defines tutuban/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_sctaircon():
    ttbnsctairconWindow = Toplevel()
    ttbnsctairconWindow.title("PNR Computing System")
    ttbnsctairconWindow.geometry("900x500+300+200")
    ttbnsctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(ttbnsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctairconWindow, text = "Yes", command = lambda:[ttbnsctdiscountaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctairconWindow, text = "No", command = lambda:[ttbnsctregularaircon(), ttbnsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines tutuban/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines tutuban/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_sctordinary():
    ttbnsctordinaryWindow = Toplevel()
    ttbnsctordinaryWindow.title("PNR Computing System")
    ttbnsctordinaryWindow.geometry("900x500+300+200")
    ttbnsctordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(ttbnsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnsctordinaryWindow, text = "Yes", command = lambda:[ttbnsctdiscountordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnsctordinaryWindow, text = "No", command = lambda:[ttbnsctregularordinary(), ttbnsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def ttbnsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
#defines tutuban to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_alabanginput():
    ttbnalbngWindow = Toplevel()
    ttbnalbngWindow.title("PNR Computing System")
    ttbnalbngWindow.geometry("900x500+300+200")
    ttbnalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ttbnalbng_label = Label(ttbnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ttbnalbng_label.place(x = 220, y = 110)
    
    ttbnalbng_aircon = Button(ttbnalbngWindow, text = "Aircon = ₱30.00", command = lambda:[tutuban_to_albngaircon(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_aircon.place(x = 250, y = 200)
    
    ttbnalbng_ordinary = Button(ttbnalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[tutuban_to_albngordinary(), ttbnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    ttbnalbng_ordinary.place(x = 460, y = 200)
 
#defines tutuban/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def tutuban_to_albngaircon():
    ttbnalbngairconWindow = Toplevel()
    ttbnalbngairconWindow.title("PNR Computing System")
    ttbnalbngairconWindow.geometry("900x500+300+200")
    ttbnalbngairconWindow.resizable(width=False, height=False)
    mainLabel = Label(ttbnalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(ttbnalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngairconWindow, text = "Yes", command = lambda:[ttbnalbngdiscountaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngairconWindow, text = "No", command = lambda:[ttbnalbngregularaircon(), ttbnalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines tutuban/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines tutuban/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.   
def tutuban_to_albngordinary():
    ttbnalbngordinaryWindow = Toplevel()
    ttbnalbngordinaryWindow.title("PNR Computing System")
    ttbnalbngordinaryWindow.geometry("900x500+300+200")
    ttbnalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(ttbnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(ttbnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(ttbnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(ttbnalbngordinaryWindow, text = "Yes", command = lambda:[ttbnalbngdiscountordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(ttbnalbngordinaryWindow, text = "No", command = lambda:[ttbnalbngregularordinary(), ttbnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines tutuban/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.   
def ttbnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines tutuban/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def ttbnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[ttbnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

    
#defines blumentritt destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def blumentritt_destination():
    newWindow4 = Toplevel()
    newWindow4.title("PNR Computing System - Blumentritt Station")
    newWindow4.geometry("900x500+300+200")
    newWindow4.resizable(width=False, height=False)
    mainLabel = Label(newWindow4, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow4, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blumentritt_sblabel = Label(newWindow4, text = "Blumentritt Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_sblabel.place(x = 460, y = 110)
    
    blumentritt_nblabel = Label(newWindow4, text = "Blumentritt Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blumentritt_nblabel.place(x = 100, y = 110)
    
    blumentritt_tutubanbtn = Button(newWindow4, text = "Tutuban", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_tutubanbtn.place(x = 200, y = 170)
    
    blumentritt_laonlaanbtn = Button(newWindow4, text = "Laon-Laan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_laonlaanbtn.place(x = 480, y = 170)
    
    blumentritt_espanabtn = Button(newWindow4, text = "Espana", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_espanabtn.place(x = 480, y = 205)
    
    blumentritt_stamesabtn = Button(newWindow4, text = "Sta. Mesa", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_stamesabtn.place(x = 480, y = 240)
    
    blumentritt_pandacanbtn = Button(newWindow4, text = "Pandacan", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pandacanbtn.place(x = 480, y = 275)
    
    blumentritt_pacobtn = Button(newWindow4, text = "Paco", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pacobtn.place(x = 480, y = 310)
    
    blumentritt_sanandresbtn = Button(newWindow4, text = "San Andres", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sanandresbtn.place(x = 480, y = 345)
    
    blumentritt_vitocruzbtn = Button(newWindow4, text = "Vito Cruz", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_vitocruzbtn.place(x = 480, y = 380)
    
    blumentritt_pasayrdbtn = Button(newWindow4, text = "Pasay Rd.", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_pasayrdbtn.place(x = 630, y = 170)
    
    blumentritt_edsabtn = Button(newWindow4, text = "EDSA", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_edsabtn.place(x = 630, y = 205)
    
    blumentritt_nicholsbtn = Button(newWindow4, text = "Nichols", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_nicholsbtn.place(x = 630, y = 240)
    
    blumentritt_ftibtn = Button(newWindow4, text = "FTI", command = lambda:[blumentritt_to_ftiinput(),newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_ftibtn.place(x = 630, y = 275)
    
    blumentritt_bicutanbtn = Button(newWindow4, text = "Bicutan", command = lambda:[blumentritt_to_bicutaninput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_bicutanbtn.place(x = 630, y = 310)
    
    blumentritt_sucatbtn = Button(newWindow4, text = "Sucat", command = lambda:[blumentritt_to_sucatinput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_sucatbtn.place(x = 630, y = 345)
    
    blumentritt_alabangbtn = Button(newWindow4, text = "Alabang", command = lambda:[blumentritt_to_alabanginput(), newWindow4.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    blumentritt_alabangbtn.place(x = 630, y = 380)
    

    
    dateLabel = Label(newWindow4, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow4, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow4, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
    
#defines blumentritt to fti as destination window 
#with labels, buttons, commands, functions, and UI design.   
def blumentritt_to_ftiinput():
    blmntrtftiWindow = Toplevel()
    blmntrtftiWindow.title("PNR Computing System")
    blmntrtftiWindow.geometry("900x500+300+200")
    blmntrtftiWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtfti_label = Label(blmntrtftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtfti_label.place(x = 220, y = 110)
    
    blmntrtfti_aircon = Button(blmntrtftiWindow, text = "Aircon = ₱15.00", command = lambda:[blumentritt_to_ftiaircon(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_aircon.place(x = 250, y = 200)
    
    blmntrtfti_ordinary = Button(blmntrtftiWindow, text = "Ordinary = ₱12.00", command = lambda:[blumentritt_to_ftiordinary(), blmntrtftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtfti_ordinary.place(x = 460, y = 200)

#defines blumentritt/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_ftiaircon():
    blmntrttftiairconWindow = Toplevel()
    blmntrttftiairconWindow .title("PNR Computing System")
    blmntrttftiairconWindow .geometry("900x500+300+200")
    blmntrttftiairconWindow .resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttftiairconWindow , text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiairconWindow , text = "Yes", command = lambda:[blmntrttftidiscountaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiairconWindow , text = "No", command = lambda:[blmntrttftiregularaircon(), blmntrttftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     

#defines blumentritt/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_ftiordinary():
    blmntrttftiordinaryWindow = Toplevel()
    blmntrttftiordinaryWindow.title("PNR Computing System")
    blmntrttftiordinaryWindow.geometry("900x500+300+200")
    blmntrttftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttftiordinaryWindow, text = "Yes", command = lambda:[blmntrttftidiscountordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttftiordinaryWindow, text = "No", command = lambda:[blmntrttftiregularordinary(), blmntrttftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design
def blmntrttftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bicutaninput():
    blmntrtbctnWindow = Toplevel()
    blmntrtbctnWindow.title("PNR Computing System")
    blmntrtbctnWindow.geometry("900x500+300+200")
    blmntrtbctnWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtbctn_label = Label(blmntrtbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtbctn_label.place(x = 220, y = 110)
    
    blmntrtbctn_aircon = Button(blmntrtbctnWindow, text = "Aircon = ₱20.00", command = lambda:[blumentritt_to_bctaircon(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_aircon.place(x = 250, y = 200)
    
    blmntrtbctn_ordinary = Button(blmntrtbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[blumentritt_to_bctordinary(), blmntrtbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtbctn_ordinary.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_bctaircon():
    blmntrttbctairconWindow = Toplevel()
    blmntrttbctairconWindow.title("PNR Computing System")
    blmntrttbctairconWindow.geometry("900x500+300+200")
    blmntrttbctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(blmntrttbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctairconWindow, text = "Yes", command = lambda:[blmntrttbctdiscountaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctairconWindow, text = "No", command = lambda:[blmntrttbctregularaircon(), blmntrttbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_bctordinary():
    blmntrttbctordinaryWindow = Toplevel()
    blmntrttbctordinaryWindow.title("PNR Computing System")
    blmntrttbctordinaryWindow.geometry("900x500+300+200")
    blmntrttbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttbctordinaryWindow, text = "Yes", command = lambda:[blmntrttbctdiscountordinary(), blmntrttbcttordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttbctordinaryWindow, text = "No", command = lambda:[blmntrttbctregularordinary(), blmntrttbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)     
    
    
#defines blumentritt to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sucatinput():
    blmntrtsctWindow = Toplevel()
    blmntrtsctWindow.title("PNR Computing System")
    blmntrtsctWindow.geometry("900x500+300+200")
    blmntrtsctWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtsctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtsctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtsct_label = Label(blmntrtsctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtsct_label.place(x = 220, y = 110)
    
    blmntrtsct_aircon = Button(blmntrtsctWindow, text = "Aircon = ₱25.00", command = lambda:[blumentritt_to_sctaircon(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_aircon.place(x = 250, y = 200)
    
    blmntrtsct_ordinary = Button(blmntrtsctWindow, text = "Ordinary = ₱20.00", command = lambda:[blumentritt_to_sctordinary(), blmntrtsctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtsct_ordinary.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_sctaircon():
    blmntrttsctairconWindow = Toplevel()
    blmntrttsctairconWindow.title("PNR Computing System")
    blmntrttsctairconWindow.geometry("900x500+300+200")
    blmntrttsctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(blmntrttsctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttsctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctairconWindow, text = "Yes", command = lambda:[blmntrttsctdiscountaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctairconWindow, text = "No", command = lambda:[blmntrttsctregularaircon(), blmntrttsctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines blumentritt/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines blumentritt/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_sctordinary():
    blmntrttsctordinaryWindow = Toplevel()
    blmntrttsctordinaryWindow.title("PNR Computing System")
    blmntrttsctordinaryWindow.geometry("900x500+300+200")
    blmntrttsctordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttsctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttsctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttsctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttsctordinaryWindow, text = "Yes", command = lambda:[blmntrttsctdiscountordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttsctordinaryWindow, text = "No", command = lambda:[blmntrttsctregularordinary(), blmntrttsctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines blumentritt/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttsctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttsctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 


#defines blumentritt to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def blumentritt_to_alabanginput():
    blmntrtalbngWindow = Toplevel()
    blmntrtalbngWindow.title("PNR Computing System")
    blmntrtalbngWindow.geometry("900x500+300+200")
    blmntrtalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrtalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrtalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    blmntrtalbng_label = Label(blmntrtalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    blmntrtalbng_label.place(x = 220, y = 110)
    
    blmntrtalbng_aircon = Button(blmntrtalbngWindow, text = "Aircon = ₱30.00", command = lambda:[blumentritt_to_albngaircon(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_aircon.place(x = 250, y = 200)
    
    blmntrtalbng_ordinary = Button(blmntrtalbngWindow, text = "Ordinary = ₱24.00", command = lambda:[blumentritt_to_albngordinary(), blmntrtalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    blmntrtalbng_ordinary.place(x = 460, y = 200)

#defines blumentritt/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngaircon():
    blmntrttalbngairconWindow = Toplevel()
    blmntrttalbngairconWindow.title("PNR Computing System")
    blmntrttalbngairconWindow.geometry("900x500+300+200")
    blmntrttalbngairconWindow.resizable(width=False, height=False)
    
    
    mainLabel = Label(blmntrttalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(blmntrttalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngairconWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngairconWindow, text = "No", command = lambda:[blmntrttalbngregularaircon(), blmntrttalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)


#defines blumentritt/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱30.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines blumentritt/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def blmntrttalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱24.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def blumentritt_to_albngordinary():
    blmntrttalbngordinaryWindow = Toplevel()
    blmntrttalbngordinaryWindow.title("PNR Computing System")
    blmntrttalbngordinaryWindow.geometry("900x500+300+200")
    blmntrttalbngordinaryWindow.resizable(width=False, height=False)
    
    mainLabel = Label(blmntrttalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(blmntrttalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(blmntrttalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(blmntrttalbngordinaryWindow, text = "Yes", command = lambda:[blmntrttalbngdiscountordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(blmntrttalbngordinaryWindow, text = "No", command = lambda:[blmntrttalbngregularordinary(), blmntrttalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines blumentritt/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱24.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines blumentritt/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def blmntrttalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱19.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[blmntrttqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laon laan destination window with all the station buttons, commands, functions,
#current time and date, and UI design.
def laonlaan_destination():
    newWindow5 = Toplevel()
    newWindow5.title("PNR Computing System - Laon-Laan Station")
    newWindow5.geometry("900x500+300+200")
    newWindow5.resizable(width=False, height=False)
    mainLabel = Label(newWindow5, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow5, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    laonlaan_sblabel = Label(newWindow5, text = "Laon-Laan Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_sblabel.place(x = 460, y = 110)
    
    laonlaan_nblabel = Label(newWindow5, text = "Laon-Laan Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    laonlaan_nblabel.place(x = 100, y = 110)
    
    laonlaan_tutubanbtn = Button(newWindow5, text = "Tutuban", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_tutubanbtn.place(x = 120, y = 170)
    
    laonlaan_blumentrittbtn = Button(newWindow5, text = "Blumentritt", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_blumentrittbtn.place(x = 270, y = 170)
    
    laonlaan_espanabtn = Button(newWindow5, text = "Espana", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_espanabtn.place(x = 480, y = 170)
    
    laonlaan_stamesabtn = Button(newWindow5, text = "Sta. Mesa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_stamesabtn.place(x = 480, y = 205)
    
    laonlaan_pandacanbtn = Button(newWindow5, text = "Pandacan", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pandacanbtn.place(x = 480, y = 240)
    
    laonlaan_pacobtn = Button(newWindow5, text = "Paco", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pacobtn.place(x = 480, y = 275)
    
    
    laonlaan_sanandresbtn = Button(newWindow5, text = "San Andres", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sanandresbtn.place(x = 480, y = 310)
    
    laonlaan_vitocruzbtn = Button(newWindow5, text = "Vito Cruz", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_vitocruzbtn.place(x = 480, y = 345 )
    
    
    laonlaan_delarosabtn = Button(newWindow5, text = "Dela Rosa", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_delarosabtn.place(x = 480, y = 380)
    
    laonlaan_pasayrdbtn = Button(newWindow5, text = "Pasay Rd.", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_pasayrdbtn.place(x = 630, y = 170)
    
    laonlaan_edsabtn = Button(newWindow5, text = "EDSA", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_edsabtn.place(x = 630, y = 205)
    
    laonlaan_nicholsbtn = Button(newWindow5, text = "Nichols", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_nicholsbtn.place(x = 630, y = 240)
    
    laonlaan_ftibtn = Button(newWindow5, text = "FTI", command = lambda:[laonlaan_to_ftiinput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_ftibtn.place(x = 630, y = 275)
    
    laonlaan_bicutanbtn = Button(newWindow5, text = "Bicutan", command = lambda:[laonlaan_to_bicutaninput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_bicutanbtn.place(x = 630, y = 310)
    
    laonlaan_sucatbtn = Button(newWindow5, text = "Sucat", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_sucatbtn.place(x = 630, y = 345 )
    
    laonlaan_alabangbtn = Button(newWindow5, text = "Alabang", command = lambda:[laonlaan_to_alabanginput(), newWindow5.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    laonlaan_alabangbtn.place(x = 630, y = 380)
      
    
    dateLabel = Label(newWindow5, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow5, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow5, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines laonlaan to fti as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_ftiinput():
    lnlnftiWindow = Toplevel()
    lnlnftiWindow.title("PNR Computing System")
    lnlnftiWindow.geometry("900x500+300+200")
    lnlnftiWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnfti_label = Label(lnlnftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnfti_label.place(x = 220, y = 110)
    
    lnlnfti_aircon = Button(lnlnftiWindow, text = "Aircon = ₱15.00", width = 15, command = lambda:[laonlaan_to_ftiaircon(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_aircon.place(x = 250, y = 200)
    
    lnlnfti_ordinary = Button(lnlnftiWindow, text = "Ordinary = ₱12.00", width = 15, command = lambda:[laonlaan_to_ftiordinary(), lnlnftiWindow.destroy()], height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnfti_ordinary.place(x = 460, y = 200)

#defines laonlaan/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiaircon():
    laonlaanftiairconWindow = Toplevel()
    laonlaanftiairconWindow.title("PNR Computing System")
    laonlaanftiairconWindow.geometry("900x500+300+200")
    laonlaanftiairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanftiairconWindow, text = "Yes", command = lambda:[lnlnftidiscountaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanftiairconWindow, text = "No", command = lambda:[lnlnftiregularaircon(), laonlaanftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines laonlaan/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_ftiordinary():
    lnlnftiordinaryWindow = Toplevel()
    lnlnftiordinaryWindow.title("PNR Computing System")
    lnlnftiordinaryWindow.geometry("900x500+300+200")
    lnlnftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnftiordinaryWindow, text = "Yes", command = lambda:[lnlnftidiscountordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnftiordinaryWindow, text = "No", command = lambda:[lnlnftiregularordinary(), lnlnftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines laonlaan/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)
     
#defines laonlaan to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_bicutaninput():
    lnlnbctnWindow = Toplevel()
    lnlnbctnWindow.title("PNR Computing System")
    lnlnbctnWindow.geometry("900x500+300+200")
    lnlnbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnbctn_label = Label(lnlnbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnbctn_label.place(x = 220, y = 110)
    
    lnlnbctn_aircon = Button(lnlnbctnWindow, text = "Aircon = ₱20.00", command = lambda:[laonlaan_to_bctaircon(), lnlnbctnWindow.destroy()],width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_aircon.place(x = 250, y = 200)
    
    lnlnbctn_ordinary = Button(lnlnbctnWindow, text = "Ordinary = ₱16.00", command = lambda:[laonlaan_to_bctordinary(), lnlnbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnbctn_ordinary.place(x = 460, y = 200)

#defines laonlaan/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctaircon():
    laonlaanbctairconWindow = Toplevel()
    laonlaanbctairconWindow.title("PNR Computing System")
    laonlaanbctairconWindow.geometry("900x500+300+200")
    laonlaanbctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(laonlaanbctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanbctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(laonlaanbctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanbctairconWindow, text = "Yes", command = lambda:[lnlnbctdiscountaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanbctairconWindow, text = "No", command = lambda:[lnlnbctregularaircon(), laonlaanbctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
 
#defines laonlaan/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.   
def lnlnbctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_bctordinary():
    lnlnbctordinaryWindow = Toplevel()
    lnlnbctordinaryWindow.title("PNR Computing System")
    lnlnbctordinaryWindow.geometry("900x500+300+200")
    lnlnbctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnbctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnbctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnbctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnbctordinaryWindow, text = "Yes", command = lambda:[lnlnbctdiscountordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnbctordinaryWindow, text = "No", command = lambda:[lnlnbctregularordinary(), lnlnbctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnbctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def laonlaan_to_alabanginput():
    lnlnalbngWindow = Toplevel()
    lnlnalbngWindow.title("PNR Computing System")
    lnlnalbngWindow.geometry("900x500+300+200")
    lnlnalbngWindow.resizable(width=False, height=False)
    
    mainLabel = Label(lnlnalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    lnlnalbng_label = Label(lnlnalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    lnlnalbng_label.place(x = 220, y = 110)
    
    lnlnalbng_aircon = Button(lnlnalbngWindow, text = "Aircon = ₱25.00", command = lambda:[laonlaan_to_albngaircon(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_aircon.place(x = 250, y = 200)
    
    lnlnalbng_ordinary = Button(lnlnalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[tutuban_to_albngordinary(), lnlnalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    lnlnalbng_ordinary.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngaircon():
    laonlaanalbngairconWindow = Toplevel()
    laonlaanalbngairconWindow.title("PNR Computing System")
    laonlaanalbngairconWindow.geometry("900x500+300+200")
    laonlaanalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(laonlaanalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(laonlaanalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(laonlaanalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(laonlaanalbngairconWindow, text = "Yes", command = lambda:[lnlnalbngdiscountaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(laonlaanalbngairconWindow, text = "No", command = lambda:[lnlnalbngregularaircon(), laonlaanalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines laonlaan/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def lnlnalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def laonlaan_to_albngordinary():
    lnlnalbngordinaryWindow = Toplevel()
    lnlnalbngordinaryWindow.title("PNR Computing System")
    lnlnalbngordinaryWindow.geometry("900x500+300+200")
    lnlnalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(lnlnalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(lnlnalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(lnlnalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(lnlnalbngordinaryWindow, text = "Yes", command = lambda:[lnlnalbngdiscountordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(lnlnalbngordinaryWindow, text = "No", command = lambda:[lnlnalbngregularordinary(), lnlnalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines laonlaan/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines laonlaan/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def lnlnalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[lnlnqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana destination window with all the station buttons, commands, functions,
#current time and date, and UI design.   
def espana_destination():
    newWindow6 = Toplevel()
    newWindow6.title("PNR Computing System - España Station")
    newWindow6.geometry("900x500+300+200")
    newWindow6.resizable(width=False, height=False)
    mainLabel = Label(newWindow6, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow6, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)   
    espana_sblabel = Label(newWindow6, text = "España Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_sblabel.place(x = 460, y = 110)
    
    espana_nblabel = Label(newWindow6, text = "España Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espana_nblabel.place(x = 100, y = 110)
    
    espana_tutubanbtn = Button(newWindow6, text = "Tutuban", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_tutubanbtn.place(x = 120, y = 170)
    
    espana_blumentrittbtn = Button(newWindow6, text = "Blumentritt", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_blumentrittbtn.place(x = 270, y = 170)
    
    espana_laonlaanbtn = Button(newWindow6, text = "Laon-Laan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_laonlaanbtn.place(x = 190, y = 205)
    
    espana_stamesabtn = Button(newWindow6, text = "Sta. Mesa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_stamesabtn.place(x = 480, y = 170)
    
    espana_pandacanbtn = Button(newWindow6, text = "Pandacan", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pandacanbtn.place(x = 480, y = 205)
    
    espana_pacobtn = Button(newWindow6, text = "Paco", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pacobtn.place(x = 480, y = 240)
    
    espana_sanandreasbtn = Button(newWindow6, text = "San Andreas", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sanandreasbtn.place(x = 480, y = 275)
    
    espana_vitocruzbtn = Button(newWindow6, text = "Vito Cruz", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_vitocruzbtn.place(x = 480, y = 310)
    
    espana_delarosabtn = Button(newWindow6, text = "Dela Rosa", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_delarosabtn.place(x = 480, y = 345)
    
    espana_pasayrdbtn = Button(newWindow6, text = "Pasay Rd.", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_pasayrdbtn.place(x = 630, y = 170)
    
    espana_edsabtn = Button(newWindow6, text = "EDSA", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_edsabtn.place(x = 630, y = 205)
    
    espana_nicholsbtn = Button(newWindow6, text = "Nichols", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_nicholsbtn.place(x = 630, y = 240)
    
    espana_ftibtn = Button(newWindow6, text = "FTI", command = lambda:[espana_to_ftiinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_ftibtn.place(x = 630, y = 275)
    
    espana_bicutanbtn = Button(newWindow6, text = "Bicutan", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_bicutanbtn.place(x = 630, y = 310)
    
    espana_sucatbtn = Button(newWindow6, text = "Sucat", command = lambda:[espana_to_sucatinput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_sucatbtn.place(x = 630, y = 345)
    
    espana_alabangbtn = Button(newWindow6, text = "Alabang", command = lambda:[espana_to_alabanginput(),newWindow6.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    espana_alabangbtn.place(x = 550, y = 380)
    
    
    dateLabel = Label(newWindow6, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow6, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow6, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()

#defines espana to fti as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiinput():
    espanaftiWindow = Toplevel()
    espanaftiWindow.title("PNR Computing System")
    espanaftiWindow.geometry("900x500+300+200")
    espanaftiWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanafti_label = Label(espanaftiWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanafti_label.place(x = 220, y = 110)
    
    espanafti_aircon = Button(espanaftiWindow, text = "Aircon = ₱15.00", command = lambda:[espana_to_ftiaircon(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_aircon.place(x = 250, y = 200)
    
    espanafti_ordinary = Button(espanaftiWindow, text = "Ordinary = ₱12.00", command = lambda:[espana_to_ftiordinary(), espanaftiWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanafti_ordinary.place(x = 460, y = 200)

#defines espana/fti/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiaircon():
    espanaftiairconWindow = Toplevel()
    espanaftiairconWindow.title("PNR Computing System")
    espanaftiairconWindow.geometry("900x500+300+200")
    espanaftiairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaftiairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaftiairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiairconWindow, text = "Yes", command = lambda:[espanaftidiscountaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiairconWindow, text = "No", command = lambda:[espanaftiregularaircon(), espanaftiairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/fti/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/fti/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaftidiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/fti/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_ftiordinary():
    espanaftiordinaryWindow = Toplevel()
    espanaftiordinaryWindow.title("PNR Computing System")
    espanaftiordinaryWindow.geometry("900x500+300+200")
    espanaftiordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaftiordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaftiordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaftiordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaftiordinaryWindow, text = "Yes", command = lambda:[espanaftidiscountordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaftiordinaryWindow, text = "No", command = lambda:[espanaftiregularordinary(), espanaftiordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/fti/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaftiregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱12.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/fti/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaftidiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱10.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    

#defines espana to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def espana_to_sucatinput():
    espanasctWindow = Toplevel()
    espanasctWindow.title("PNR Computing System")
    espanasctWindow.geometry("900x500+300+200")
    espanasctWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanasct_label = Label(espanasctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanasct_label.place(x = 220, y = 110)
    
    espanasct_aircon = Button(espanasctWindow, text = "Aircon = ₱20.00", command = lambda:[espana_to_sucataircon(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_aircon.place(x = 250, y = 200)
    
    espanasct_ordinary = Button(espanasctWindow, text = "Ordinary = ₱16.00", command = lambda:[espana_to_sucatordinary(), espanasctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanasct_ordinary.place(x = 460, y = 200)

#defines espana/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucataircon():
    espanasctairconWindow = Toplevel()
    espanasctairconWindow.title("PNR Computing System")
    espanasctairconWindow.geometry("900x500+300+200")
    espanasctairconWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    
    airconLabel = Label(espanasctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctairconWindow, text = "Yes", command = lambda:[espanasctdiscountaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctairconWindow, text = "No", command = lambda:[espanasctregularaircon(), espanasctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_sucatordinary():
    espanasctordinaryWindow = Toplevel()
    espanasctordinaryWindow.title("PNR Computing System")
    espanasctordinaryWindow.geometry("900x500+300+200")
    espanasctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanasctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanasctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanasctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanasctordinaryWindow, text = "Yes", command = lambda:[espanasctdiscountordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanasctordinaryWindow, text = "No", command = lambda:[espanasctregularordinary(), espanasctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabanginput():
    espanaalbngWindow = Toplevel()
    espanaalbngWindow.title("PNR Computing System")
    espanaalbngWindow.geometry("900x500+300+200")
    espanaalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    espanaalbng_label = Label(espanaalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    espanaalbng_label.place(x = 220, y = 110)
    
    espanaalbng_aircon = Button(espanaalbngWindow, text = "Aircon = ₱25.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_aircon.place(x = 250, y = 200)
    
    espanaalbng_ordinary = Button(espanaalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[espana_to_alabangaircon(), espanaalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    espanaalbng_ordinary.place(x = 460, y = 200)

#defines espana/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangaircon():
    espanaalbngairconWindow = Toplevel()
    espanaalbngairconWindow.title("PNR Computing System")
    espanaalbngairconWindow.geometry("900x500+300+200")
    espanaalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(espanaalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(espanaalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngairconWindow, text = "Yes", command = lambda:[espanaalbngdiscountaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngairconWindow, text = "No", command = lambda:[espanaalbngregularaircon(), espanaalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines espana/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[espanaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines espana/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[espanaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines espana/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def espana_to_alabangordinary():
    espanaalbngordinaryWindow = Toplevel()
    espanaalbngordinaryWindow.title("PNR Computing System")
    espanaalbngordinaryWindow.geometry("900x500+300+200")
    espanaalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(espanaalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(espanaalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(espanaalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(espanaalbngordinaryWindow, text = "Yes", command = lambda:[espanaalbngdiscountordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(espanaalbngordinaryWindow, text = "No", command = lambda:[espanaalbngregularordinary(), espanaalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines espana/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.    
def espanaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[espanaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines espana/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def espanaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)   

#defines sta.mesa destination window with all the station buttons, commands, functions,
#current time and date, and UI design.    
def stamesa_destination():
    newWindow7 = Toplevel()
    newWindow7.title("PNR Computing System - Sta. Mesa Station")
    newWindow7.geometry("900x500+300+200")
    newWindow7.resizable(width=False, height=False)
    mainLabel = Label(newWindow7, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(newWindow7, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    stamesa_sblabel = Label(newWindow7, text = "Sta. Mesa Southbound Destination List", width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_sblabel.place(x = 460, y = 110)
    
    stamesa_nblabel = Label(newWindow7, text = "Sta. Mesa Northbound Destination List",  width = 35, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stamesa_nblabel.place(x = 100, y = 110)
    
    stamesa_tutubanbtn = Button(newWindow7, text = "Tutuban", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_tutubanbtn.place(x = 120, y = 170)
    
    stamesa_blumentrittbtn = Button(newWindow7, text = "Blumentritt", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_blumentrittbtn.place(x = 270, y = 170)
    
    
    stamesa_laonlaanbtn = Button(newWindow7, text = "Laon-Laan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_laonlaanbtn.place(x = 120, y = 205)
    
    stamesa_espanabtn = Button(newWindow7, text = "Espana", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_espanabtn.place(x = 270, y = 205)
    
    
    stamesa_pandacanbtn = Button(newWindow7, text = "Pandacan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pandacanbtn.place(x = 480, y = 170)
    
    stamesa_pacobtn = Button(newWindow7, text = "Paco", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pacobtn.place(x = 480, y = 205)
    
    stamesa_sanandresbtn = Button(newWindow7, text = "San Andres", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sanandresbtn.place(x = 480, y = 240)
    
    stamesa_vitocruzbtn = Button(newWindow7, text = "Vito Cruz", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_vitocruzbtn.place(x = 480, y = 275)
    
    stamesa_delarosabtn = Button(newWindow7, text = "Dela Rosa", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_delarosabtn.place(x = 480, y = 310)
    
    stamesa_pasayrdbtn = Button(newWindow7, text = "Pasay Rd.", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_pasayrdbtn.place(x = 480, y = 345)
    
    stamesa_edsabtn = Button(newWindow7, text = "EDSA", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_edsabtn.place(x = 630, y = 170)
    
    stamesa_nicholsbtn = Button(newWindow7, text = "Nichols", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_nicholsbtn.place(x = 630, y = 205)
    
    stamesa_ftibtn = Button(newWindow7, text = "FTI", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_ftibtn.place(x = 630, y = 240)
    
    stamesa_bicutanbtn = Button(newWindow7, text = "Bicutan", command = lambda:[stamesa_to_bicutaninput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_bicutanbtn.place(x = 630, y = 275)
    
    stamesa_sucatbtn = Button(newWindow7, text = "Sucat", command = lambda:[stamesa_to_sucatinput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_sucatbtn.place(x = 630, y = 310)
    
    stamesa_alabangbtn = Button(newWindow7, text = "Alabang", command = lambda:[stamesa_to_alabanginput(), newWindow7.destroy()], width = 15, height = 1, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 10))
    stamesa_alabangbtn.place(x = 630, y = 345)
    
    
    dateLabel = Label(newWindow7, text=f"{date:%A, %B %d, %Y}", font=("Microsoft YaHei UI Light", 10))
    dateLabel.place(x = 720, y = 50)

    pstLabel = Label(newWindow7, text= "Philippine Standard Time" , font=("Microsoft YaHei UI Light", 10, 'bold'))
    pstLabel.place(x = 700, y = 30)


    timeLabel = Label(newWindow7, font=("Microsoft YaHei UI Light", 15, 'bold'), fg="black")

    def clock():
        text_input = time.strftime("%I:%M:%S %p")
        timeLabel.config(text=text_input)
        timeLabel.after(200, clock)
        timeLabel.place(x = 750, y = 70)

    clock()
        

#defines sta.mesa to bicutan as destination window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutaninput():
    stmsbctnWindow = Toplevel()
    stmsbctnWindow.title("PNR Computing System")
    stmsbctnWindow.geometry("900x500+300+200")
    stmsbctnWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsbctn_label = Label(stmsbctnWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsbctn_label.place(x = 220, y = 110)
    
    stmsbctn_aircon = Button(stmsbctnWindow, text = "Aircon = ₱15.00", command = lambda:[stamesa_to_bicutanaircon(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_aircon.place(x = 250, y = 200)
    
    stmsbctn_ordinary = Button(stmsbctnWindow, text = "Ordinary = ₱12.00", command = lambda:[stamesa_to_bicutanordinary(), stmsbctnWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsbctn_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/bicutan/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_bicutanaircon():
    stmsbctnairconWindow = Toplevel()
    stmsbctnairconWindow.title("PNR Computing System")
    stmsbctnairconWindow.geometry("900x500+300+200")
    stmsbctnairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsbctnairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsbctnairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnairconWindow, text = "Yes", command = lambda:[stamesabctndiscountaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnairconWindow, text = "No", command = lambda:[stamesabctnregularaircon(), stmsbctnairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/bicutan/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱15.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/bicutan/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesabctndiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱12.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400)

#defines sta.mesa/bicutan/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_bicutanordinary():
    stmsbctnordinaryWindow = Toplevel()
    stmsbctnordinaryWindow.title("PNR Computing System")
    stmsbctnordinaryWindow.geometry("900x500+300+200")
    stmsbctnordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsbctnordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsbctnordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsbctnordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsbctnordinaryWindow, text = "Yes", command = lambda:[stamesabctndiscountordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsbctnordinaryWindow, text = "No", command = lambda:[stamesabctnregularordinary(), stmsbctnordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/bicutan/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctnregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/bicutan/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesabctndiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa to sucat as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatinput():
    stmssctWindow = Toplevel()
    stmssctWindow.title("PNR Computing System")
    stmssctWindow.geometry("900x500+300+200")
    stmssctWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmssct_label = Label(stmssctWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmssct_label.place(x = 220, y = 110)
    
    stmssct_aircon = Button(stmssctWindow, text = "Aircon = ₱20.00", command = lambda:[stamesa_to_sucataircon(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_aircon.place(x = 250, y = 200)
    
    stmssct_ordinary = Button(stmssctWindow, text = "Ordinary = ₱16.00", command = lambda:[stamesa_to_sucatordinary(), stmssctWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmssct_ordinary.place(x = 460, y = 200)

#defines sta.mesa/sucat/aircon window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_sucataircon():
    stmssctairconWindow = Toplevel()
    stmssctairconWindow.title("PNR Computing System")
    stmssctairconWindow.geometry("900x500+300+200")
    stmssctairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmssctairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmssctairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctairconWindow, text = "Yes", command = lambda:[stamesasctdiscountaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctairconWindow, text = "No", command = lambda:[stamesasctregularaircon(), stmssctairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)
    
#defines sta.mesa/sucat/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/sucat/ordinary window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_sucatordinary():
    stmssctordinaryWindow = Toplevel()
    stmssctordinaryWindow.title("PNR Computing System")
    stmssctordinaryWindow.geometry("900x500+300+200")
    stmssctordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmssctordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmssctordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmssctordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmssctordinaryWindow, text = "Yes", command = lambda:[stamesasctdiscountordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmssctordinaryWindow, text = "No", command = lambda:[stamesasctregularordinary(), stmssctordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/sucat/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesasctregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱16.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/sucat/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesasctdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱13.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
    
#defines sta.mesa to alabang as destination window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabanginput():
    stmsalbngWindow = Toplevel()
    stmsalbngWindow.title("PNR Computing System")
    stmsalbngWindow.geometry("900x500+300+200")
    stmsalbngWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    stmsalbng_label = Label(stmsalbngWindow, text = "Choose your train type below. ",  width = 45, height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    stmsalbng_label.place(x = 220, y = 110)
    
    stmsalbng_aircon = Button(stmsalbngWindow, text = "Aircon = ₱25.00", command = lambda:[stamesa_to_alabangaircon(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_aircon.place(x = 250, y = 200)
    
    stmsalbng_ordinary = Button(stmsalbngWindow, text = "Ordinary = ₱20.00", command = lambda:[stamesa_to_alabangordinary(), stmsalbngWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    stmsalbng_ordinary.place(x = 460, y = 200) 
    
#defines sta.mesa/alabang/aircon window 
#with labels, buttons, commands, functions, and UI design.    
def stamesa_to_alabangaircon():
    stmsalbngairconWindow = Toplevel()
    stmsalbngairconWindow.title("PNR Computing System")
    stmsalbngairconWindow.geometry("900x500+300+200")
    stmsalbngairconWindow.resizable(width=False, height=False)
    
    mainLabel = Label(stmsalbngairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    airconLabel = Label(stmsalbngairconWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    airconLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngairconWindow, text = "Yes", command = lambda:[stamesaalbngdiscountaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngairconWindow, text = "No", command = lambda:[stamesaalbngregularaircon(), stmsalbngairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/aircon/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularaircon():
    regularairconWindow = Toplevel()
    regularairconWindow.title("PNR Computing System")
    regularairconWindow.geometry("900x500+300+200")
    regularairconWindow.resizable(width=False, height=False)
    mainLabel = Label(regularairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regairconLabel = Label(regularairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 220, y = 110)
    
    regairconLabel = Label(regularairconWindow, text = "Regular fare = ₱25.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    
#defines sta.mesa/alabang/aircon/discounted window 
#with labels, buttons, commands, functions, and UI design.    
def stamesaalbngdiscountaircon():
    discountairconWindow = Toplevel()
    discountairconWindow.title("PNR Computing System")
    discountairconWindow.geometry("900x500+300+200")
    discountairconWindow.resizable(width=False, height=False)
    mainLabel = Label(discountairconWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountairconWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    discairconLabel = Label(discountairconWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 220, y = 110)
    
    discairconLabel = Label(discountairconWindow, text = "Discounted fare = ₱20.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discairconLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountairconWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountairconWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary window 
#with labels, buttons, commands, functions, and UI design.
def stamesa_to_alabangordinary():
    stmsalbngordinaryWindow = Toplevel()
    stmsalbngordinaryWindow.title("PNR Computing System")
    stmsalbngordinaryWindow.geometry("900x500+300+200")
    stmsalbngordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(stmsalbngordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(stmsalbngordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)
    ordinaryLabel = Label(stmsalbngordinaryWindow, text = "Are you a senior citizen or PWD?", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    ordinaryLabel.place(x = 220, y = 110)
    
    discanswer = Button(stmsalbngordinaryWindow, text = "Yes", command = lambda:[stamesaalbngdiscountordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    discanswer.place(x = 250, y = 200)
    
    reganswer = Button(stmsalbngordinaryWindow, text = "No", command = lambda:[stamesaalbngregularordinary(), stmsalbngordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    reganswer.place(x = 460, y = 200)

#defines sta.mesa/alabang/ordinary/regular window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngregularordinary():
    regularordinaryWindow = Toplevel()
    regularordinaryWindow.title("PNR Computing System")
    regularordinaryWindow.geometry("900x500+300+200")
    regularordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(regularordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(regularordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(regularordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    regordinaryLabel = Label(regularordinaryWindow, text = "Regular fare = ₱20.00.\n Please pay upon the cashier to get your ticket.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(regularordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), regularordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 

#defines sta.mesa/alabang/ordinary/discounted window 
#with labels, buttons, commands, functions, and UI design.
def stamesaalbngdiscountordinary():
    discountordinaryWindow = Toplevel()
    discountordinaryWindow.title("PNR Computing System")
    discountordinaryWindow.geometry("900x500+300+200")
    discountordinaryWindow.resizable(width=False, height=False)
    mainLabel = Label(discountordinaryWindow, text = "", fg = "white", bg = "#FF8552", width = 100, height = 1, font=("Open Sans", 12))
    mainLabel.pack()
    botLabel = Label(discountordinaryWindow, fg = "white", bg = "#FF8552", width = 150, height = 1)
    botLabel.place(y=480)    
    regordinaryLabel = Label(discountordinaryWindow, text = "TOTAL BREAKDOWN", width = 45 , height = 3, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    regordinaryLabel.place(x = 220, y = 110)
    
    discordinaryLabel = Label(discountordinaryWindow, text = "Discounted fare = ₱16.00.\n Please prepare your PWD or Senior Citizen ID upon paying.", width = 55 , height = 6, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 13))
    discordinaryLabel.place(x = 170, y = 220)
    
    confirmBtn = Button(discountordinaryWindow, text = "Confirm", command = lambda:[stamesaqueue(), discountordinaryWindow.destroy()], width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
    confirmBtn.place(x = 650, y = 400) 
    


#defines tutuban station queueing window 
#with label, boolean expressions, button and UI design.
def ttbnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 3" in the queue
    passenger_queue_tutuban.append('User 3')
    
    if len(passenger_queue_tutuban) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_tutuban) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_tutuban) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
#defines blumentritt station queueing window 
#with label, boolean expressions, button and UI design.        
def blmntrttqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 3" in the queue
    passenger_queue_blumentritt.append('User 3')
    if len(passenger_queue_blumentritt) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_blumentritt) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_blumentritt) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines laon-laan station queueing window 
#with label, boolean expressions, button and UI design.
def lnlnqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 3" in the queue
    passenger_queue_laonlaan.append('User 3')
    if len(passenger_queue_laonlaan) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_laonlaan) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_laonlaan) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
                         
#defines espana station queueing window 
#with label, boolean expressions, button and UI design.
def espanaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 3" in the queue
    passenger_queue_espana.append('User 3')
    if len(passenger_queue_espana) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_espana) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_espana) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)

#defines sta.mesa station queueing window 
#with label, boolean expressions, button and UI design.
def stamesaqueue():
    queueWindow = Toplevel()
    queueWindow.title("PNR Computing System")
    queueWindow.geometry("900x500+300+200")
    queueWindow.resizable(width=False, height=False)
    
    #append or add the 'User 3" in the queue
    passenger_queue_stamesa.append('User 3')
    if len(passenger_queue_stamesa) == 1:
        queueLabel = Label(queueWindow, text = "You're #1 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
    
    elif len(passenger_queue_stamesa) == 2:
        queueLabel = Label(queueWindow, text = "You're #2 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 3:
        queueLabel = Label(queueWindow, text = "You're #3 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 4:
        queueLabel = Label(queueWindow, text = "You're #4 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)
        
    elif len(passenger_queue_stamesa) == 5:
        queueLabel = Label(queueWindow, text = "You're #5 in the queue.", width = 45 , height = 10, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 20))
        queueLabel.place(x = 100, y = 55)
        confirmBtn = Button(queueWindow, text = "Confirm", command = queueWindow.destroy, width = 15, height = 2, bg= "#188FFF", fg = "white", font = ("Open Sans Bold", 11))
        confirmBtn.place(x = 650, y = 400)


#method to execute in running the window
root.mainloop()

#References:
#https://www.tutorialspoint.com/python-to-create-a-digital-clock-using-tkinter
#https://realpython.com/python-gui-tkinter/#:~:text=Python%20has%20a%20lot%20of,Windows%2C%20macOS%2C%20and%20Linux.
#https://discuss.codecademy.com/t/how-to-convert-to-12-hour-clock/3920/3
#https://stackoverflow.com/questions/2416486/how-to-create-a-password-entry-field-using-tkinter
#https://www.youtube.com/watch?v=c3rp-iKe3cI&ab_channel=GeeksforGeeks
# photo of pnr - https://en.wikipedia.org/wiki/PNR_8000_class
#https://stackoverflow.com/questions/39416021/border-for-tkinter-label
#https://www.youtube.com/watch?v=7A_csP9drJw&list=LL&index=1&t=260s&ab_channel=Codemy.com
#https://stackoverflow.com/questions/13865009/have-multiple-commands-when-button-is-pressed

# %% [markdown]
# # Checking for queues

# %%
len(passenger_queue_tutuban) #check how many in queues are in tutuban station
# Out:
# 0

# %%
len(passenger_queue_blumentritt) #check how many in queues are in blumentritt station
# Out:
# 0

# %%
len(passenger_queue_laonlaan) #check how many in queues are in laon-laan station
# Out:
# 0

# %%
len(passenger_queue_espana) #check how many in queues are in espana station
# Out:
# 0

# %%
len(passenger_queue_stamesa) #check how many in queues are in sta.mesa station
# Out:
# 0

# %%
print(passenger_queue_tutuban) #check each passenger who are in queue
# Out:
# []

# %%
print(passenger_queue_blumentritt) #check each passenger who are in line queue for blumentritt station
# Out:
# []

# %%
print(passenger_queue_laonlaan) #check each passenger who are in line queue for laon-laan station
# Out:
# []

# %%
print(passenger_queue_espana) #check each passenger who are in line queue for espana station
# Out:
# []

# %%
print(passenger_queue_stamesa) #check each passenger who are in line queue for sta.mesa station
# Out:
# []

# %%
passenger_queue_tutuban.pop(0) #pop the 1st user out of the tutuban station queue in paying the cashier
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4904/2996841852.py in <module>
# ----> 1 passenger_queue_tutuban.pop(0) #pop the 1st user out of the tutuban station queue in paying the cashier
#
# IndexError: pop from empty list

# %%
passenger_queue_blumentritt.pop(0) #pop the 1st user out of the tutuban station queue in paying the cashier
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4904/3971454086.py in <module>
# ----> 1 passenger_queue_blumentritt.pop(0) #pop the 1st user out of the tutuban station queue in paying the cashier
#
# IndexError: pop from empty list

# %%
passenger_queue_laonlaan.pop(0) #pop the 1st user out of the laon laan station queue in paying the cashier
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4904/317322125.py in <module>
# ----> 1 passenger_queue_laonlaan.pop(0) #pop the 1st user out of the laon laan station queue in paying the cashier
#
# IndexError: pop from empty list

# %%
passenger_queue_espana.pop(0) #pop the 1st user out of the espana station queue in paying the cashier
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4904/3246842679.py in <module>
# ----> 1 passenger_queue_espana.pop(0) #pop the 1st user out of the espana station queue in paying the cashier
#
# IndexError: pop from empty list

# %%
passenger_queue_stamesa.pop(0) #pop the 1st user out of the sta.mesa station queue in paying the cashier
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4904/1871103027.py in <module>
# ----> 1 passenger_queue_stamesa.pop(0) #pop the 1st user out of the sta.mesa station queue in paying the cashier
#
# IndexError: pop from empty list
